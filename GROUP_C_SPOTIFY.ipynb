# %% [markdown]
# # SPARK - SPOTIFY PROJECT
#
# **Group C**
# -  Nikolas Artadi
# -  Camila Vasquez
# -  Assemgul Khametova
# -  Miguel Frutos
#
# Spotify-Data 1921-2020
# Audio features of songs from 1921-2020
#
# The "data.csv" file contains more than 160.000 songs collected from Spotify Web API. The dataset is from Spotify and contains 169k songs from the year 1921 to year 2020. Each year got
# top 100 songs.
#
# **OBJECTIVE**
# - Analyze the trends of songs over the course of a century.
# - Build a content-based recommendation engine which suggests artists.
# - Find Influential Artists in Different Genres.
# - Predict popularity of song based on other features.
# - Cluster different genres according to audio features.
#
# Sources: <br>
# 1- https://www.kaggle.com/ektanegi/spotifydata-19212020?select=data.csv <br>
# 2- https://developer.spotify.com/discover/<br>
# 3- https://towardsdatascience.com/k-means-clustering-and-pca-to-categorize-music-by-similar-audio-features-df09c93e8b64<br>
# 4- https://towardsdatascience.com/8-data-science-project-ideas-from-kaggle-in-2021-83a3660e0342 <br>
#
# Let's go for it:

# %% [markdown]
# # STRUCTURE/INDEX OF THE PROJECT
# **1- SET UP**
# - PySpark environment,
# - Data source
# - Spark data abstraction (DataFrame)
#
# **2- EXPLORE**
# - Explore Dataset
# - Explore Columns
#
# **3- BUSINESS QUESTIONS**
#
# **4- FREE STYLE & SKETCHES**

# %% [markdown]
# # 1. SETUP
# - PySpark environment,
# - Data source
# - Spark data abstraction (DataFrame)

# %%
#This is specific for our course enviroment (to set up).
#If our enviroment was the one provided by Databricks, we wont need these two lines but the Azure Databricks Cluster
import findspark
findspark.init()

#importing Python packages and connecting our code through the Spark Cluster

from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession

#This is in every spark jobs. Enables the access to Spark session.

sc = SparkContext.getOrCreate()
spark = SparkSession(sc)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark3/jars/spark-unsafe_2.12-3.0.3.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
#First, access to the data source. Reading the CSV files calling funtions.
#Way of reading the file: InferSchema, telling spark that there is a header and where the file is located.
#As there are some commas inside the schema we should escape them with the underlying double quotes.
spotify = spark.read \
                 .option("inferSchema", "true") \
                 .option("header", "true") \
                 .option("quote", "\"")\
                 .option("escape", "\"")\
                 .csv("data.csv") \
                 .cache() # optimization to make the processing faster. 
                        #Keep the processing in the cache.

# %% [markdown]
# # 2. EXPLORE

# %% [markdown]
# ## A. EXPLORE DATASET

# %% [markdown]
# Identify the Data Types and Description of the Features
#
# **PRIMARY KEY**:
# - id (Id of track generated by Spotify)
#
# **NUMERICAL VARIABLES**:
# - **acousticness** [0-1] - Confidence measure of whether the track is acoustic.
# - **danceability** [0–1] - Describes how suitable a track is for dancing based on musical attributes including tempo, rhythm, stability, beat strength, and overall regularity.
# - **energy** [0–1]- Perceptual measure of intensity and activity. Energetic tracks feel fast, loud, and noisy (e.g. death metal: high energy, Bach prelude: low energy).
# - **duration_ms** [Integer typically 200k to 300k]
# - **instrumentalness** [0–1] - Predicts whether a track contains no vocals (values above 0.5 represent instrumental tracks whereas rap songs would have a score close to 0).
# - **valence** [0–1] - Describes the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# - **popularity** [0–100]
# - **tempo** [Float typically 50 to 150] - The speed or pace of a given piece, as derived from the estimated average beat duration.
# - **liveness** [0–1] - Detects the presence of an audience in the recording.
# - **loudness** [Float typically -60 to 0] - The average volume across an entire track.
# - **speechiness** [0–1] - Detects the presence of spoken words in a track (values above 0.66 describe tracks that are probably made entirely of spoken words, 0.33–0.66 describe tracks that may contain both music and speech, and values below 0.33 most likely represent music and other non-speech-like tracks).
# - **year** [1921- 2020]
#
# **DUMMY VARIABLES**:
# - **mode**: 0 = Minor, 1 = Major
# - **explicit** : 0 = No explicit content, 1 = Explicit content.
#
# **CATEGORICAL VARIABLES**:
# - **key**: All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…
# - **artists**: List of artists mentioned.
# - **release_date**: Date of release mostly in yyyy-mm-dd format, however precision of date may vary
# - **name**: Name of the song.

# %% [markdown]
# ### Column categorization
# - **Timing related columns**: *duration_ms,year,release_date.*
# - **Song Characteristics**: *accousticness, instrumentalness, tempo, loudness, speechiness, key, mode, explicit.*
# - **Song Effects**: *danceability, energy, valence, popularity,liveness.*
# - **Issue related columns**: *name, artists.*

# %% [markdown]
# ### Display schema and size of the DataFrame

# %%
#Import additional python packages
#The last function is not so relevant for the group assignment, Raul prefers an effective code rather than fancy code lines.
#printSchema and spotify.counts are ACTIONS!!!
#".count()" Returns the number of rows.
from IPython.display import display, Markdown
spotify.printSchema()
display(Markdown("This DataFrame has **%d rows**." % spotify.count()))
# Out:
# root
#  |-- acousticness: double (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- duration_ms: integer (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- explicit: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- year: integer (nullable = true)
# This DataFrame has **169909 rows**.

# %%
#Return the schema of this Spotify Dataframe pyspark.sql.types.StrucType
spotify.schema
# Out:
# StructType(List(StructField(acousticness,DoubleType,true),StructField(artists,StringType,true),StructField(danceability,DoubleType,true),StructField(duration_ms,IntegerType,true),StructField(energy,DoubleType,true),StructField(explicit,IntegerType,true),StructField(id,StringType,true),StructField(instrumentalness,DoubleType,true),StructField(key,IntegerType,true),StructField(liveness,DoubleType,true),StructField(loudness,DoubleType,true),StructField(mode,IntegerType,true),StructField(name,StringType,true),StructField(popularity,IntegerType,true),StructField(release_date,StringType,true),StructField(speechiness,DoubleType,true),StructField(tempo,DoubleType,true),StructField(valence,DoubleType,true),StructField(year,IntegerType,true)))

# %% [markdown]
# As there are 37 columns inside our dataframe, it is more user-friendly and visual to represent the dataset through pandas layout.

# %%
#"toPandas()"returns content as a Pandas Dataframe
spotify.toPandas()
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# 0            158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1            282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2            104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3            180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4            687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
# ...             ...     ...       ...                     ...
# 169904       163800  0.4430         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700  0.5390         0  52eycxprLhK3lPcRLbQiVk
# 169907       167308  0.7610         0  3wYOGJYD31sLRmBgCvWxa4
# 169908       214787  0.4280         0  60RFlt48hm0l4Fu0JoccOl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.563000   10    0.1510   -12.428     1
# 1               0.901000    8    0.0763   -28.454     1
# 2               0.000000    5    0.1190   -19.924     0
# 3               0.887000    1    0.1110   -14.734     0
# 4               0.908000   11    0.0980   -16.829     1
# ...                  ...  ...       ...       ...   ...
# 169904          0.000032    1    0.0891    -7.461     1
# 169905          0.031300    8    0.1110   -10.907     1
# 169906          0.002330    7    0.1080    -9.332     1
# 169907          0.000000    1    0.2220    -2.557     1
# 169908          0.000000    0    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year
# 0              1928       0.0506  118.469   0.7790  1928
# 1              1928       0.0462   83.972   0.0767  1928
# 2              1928       0.9290  107.177   0.8800  1928
# 3        1928-09-25       0.0926  108.003   0.7200  1928
# 4              1928       0.0424   62.149   0.0693  1928
# ...             ...          ...      ...      ...   ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020
# 169905   2020-06-08       0.0403  128.000   0.2700  2020
# 169906   2020-05-29       0.1050  123.700   0.1530  2020
# 169907   2020-02-28       0.0385  129.916   0.4720  2020
# 169908   2020-03-27       0.0271   80.588   0.3660  2020
#
# [169909 rows x 19 columns]

# %% [markdown]
# ### Data Quality from the surface

# %% [markdown]
# Checking if there are missing/null values inside spotify dataset

# %%
#Using list comprehension to check if there is null values.
from pyspark.sql.functions import isnan, when, count, col

spotify.select([count(when(isnan(c), c)).alias(c) for c in spotify.columns]).toPandas()
# Out:
#    acousticness  artists  danceability  duration_ms  energy  explicit  id  \
# 0             0        0             0            0       0         0   0
#
#    instrumentalness  key  liveness  loudness  mode  name  popularity  \
# 0                 0    0         0         0     0     0           0
#
#    release_date  speechiness  tempo  valence  year
# 0             0            0      0        0     0

# %% [markdown]
# Checking if the distinct values are the expected:
# - Explicit: 2
# - id: Same as the nº of rows (169909)
# - key:12
# - mode:2
# - year: 100

# %%
from pyspark.sql.functions import countDistinct
print("Checking amount of distinct values in columns Year, Month, DayofMonth and DayOfWeek:")
spotify.select([countDistinct(c).alias(c) for c in spotify.columns]).toPandas()
# Out:
# Checking amount of distinct values in columns Year, Month, DayofMonth and DayOfWeek:
#    acousticness  artists  danceability  duration_ms  energy  explicit      id  \
# 0          4714    33375          1232        50212    2332         2  169909
#
#    instrumentalness  key  liveness  loudness  mode    name  popularity  \
# 0              5401   12      1741     25313     2  132940         100
#
#    release_date  speechiness  tempo  valence  year
# 0         10882         1628  84548     1739   100

# %% [markdown]
# ## B. EXPLORE COLUMNS

# %%
#column names of the spotify dataframe as a list
spotify.columns
# Out:
# ['acousticness',
#  'artists',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'explicit',
#  'id',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'name',
#  'popularity',
#  'release_date',
#  'speechiness',
#  'tempo',
#  'valence',
#  'year']

# %% [markdown]
# Statistics about the different columns

# %%
#".summary" specify statistics
#".select" specify columns
#".show" triggers the action
#".describe(cols)" get the basic statistics for numeric and string columns. Very similar.
spotify.select('*').summary("count", "min", "25%", "75%", "max",'mean','stddev').toPandas()
# Out:
#   summary         acousticness  \
# 0   count               169909
# 1     min                  0.0
# 2     25%               0.0944
# 3     75%                0.888
# 4     max                0.996
# 5    mean    0.493213976149875
# 6  stddev  0.37662706233783233
#
#                                              artists         danceability  \
# 0                                             169909               169909
# 1  ["'In The Heights' Original Broadway Company",...                  0.0
# 2                                               None                0.417
# 3                                               None                0.667
# 4                                             ['黑豹']                0.988
# 5                                               None   0.5381497172015581
# 6                                               None  0.17534578204760803
#
#           duration_ms               energy             explicit  \
# 0              169909               169909               169909
# 1                5108                  0.0                    0
# 2              171040                0.263                    0
# 3              262943                 0.71                    0
# 4             5403500                  1.0                    1
# 5   231406.1589733328   0.4885931303603691  0.08486307376301432
# 6  121321.92321940271  0.26738993295713437  0.27867864925974417
#
#                        id     instrumentalness                 key  \
# 0                  169909               169909              169909
# 1  000G1xMMuwxNHmwVsBdtj1                  0.0                   0
# 2                    None                  0.0                   2
# 3                    None               0.0868                   8
# 4  7zzuPsjj9L3M7ikqGmjN0D                  1.0                  11
# 5                    None  0.16193714313891427   5.200519101401339
# 6                    None  0.30932888203837267  3.5152567984248693
#
#               liveness             loudness                 mode  \
# 0               169909               169909               169909
# 1                  0.0                -60.0                    0
# 2               0.0984               -14.47                    0
# 3                0.263               -7.119                    1
# 4                  1.0                3.855                    1
# 5  0.20669034936348246  -11.370289301920401   0.7085557563166165
# 6   0.1767964903942966   5.6667646295717695  0.45442899544073423
#
#                                   name          popularity  \
# 0                               169909              169909
# 1            !Que Vida! - Mono Version                   0
# 2                                 24.0                  12
# 3                               1980.0                  48
# 4  화려하지 않은 고백 Confession Is Not Flashy                 100
# 5                             Infinity   31.55660971461194
# 6                                  NaN  21.582613808557902
#
#          release_date          speechiness               tempo  \
# 0              169909               169909              169909
# 1                1921                  0.0                 0.0
# 2              1948.0               0.0349              93.519
# 3              1980.0               0.0754               135.7
# 4          2020-06-18                0.969             244.091
# 5  1963.7319876146244  0.09405769441288801  116.94801737400672
# 6  21.570826832323228  0.14993730259926946  30.726936654886917
#
#                valence                year
# 0               169909              169909
# 1                  0.0                1921
# 2                0.322                1957
# 3   0.7490000000000001                1999
# 4                  1.0                2020
# 5   0.5320951423473788  1977.2232312590857
# 6  0.26240763092035796  25.593167631762732

# %%
#Changing column datatype
#.cast (IntegerType()) -----> convert the column into integer.
from pyspark.sql.types import StringType
from pyspark.sql.types import IntegerType
from pyspark.sql.types import FloatType
from pyspark.sql.types import DateType
from pyspark.sql.types import BooleanType
spotify_types = spotify \
    .withColumn('acousticness',col('acousticness').cast(FloatType())) \
    .withColumn('artists',col('artists').cast(StringType())) \
    .withColumn('danceability',col('danceability').cast(FloatType())) \
    .withColumn('duration_ms',col('duration_ms').cast(IntegerType())) \
    .withColumn('energy',col('energy').cast(FloatType())) \
    .withColumn('explicit',col('explicit').cast(BooleanType())) \
    .withColumn('id',col('id').cast(StringType())) \
    .withColumn('instrumentalness',col('instrumentalness').cast(FloatType())) \
    .withColumn('key',col('key').cast(IntegerType())) \
    .withColumn('liveness',col('liveness').cast(FloatType())) \
    .withColumn('loudness',col('loudness').cast(FloatType())) \
    .withColumn('mode',col('mode').cast(BooleanType())) \
    .withColumn('name',col('name').cast(StringType())) \
    .withColumn('popularity',col('popularity').cast(IntegerType())) \
    .withColumn('release_date',col('release_date').cast(DateType())) \
    .withColumn('speechiness',col('speechiness').cast(FloatType())) \
    .withColumn('tempo',col('tempo').cast(FloatType())) \
    .withColumn('valence',col('valence').cast(FloatType())) \
    .withColumn('year',col('year').cast(IntegerType())) \

spotify_types.printSchema()
# Out:
# root
#  |-- acousticness: float (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- danceability: float (nullable = true)
#  |-- duration_ms: integer (nullable = true)
#  |-- energy: float (nullable = true)
#  |-- explicit: boolean (nullable = true)
#  |-- id: string (nullable = true)
#  |-- instrumentalness: float (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- liveness: float (nullable = true)
#  |-- loudness: float (nullable = true)
#  |-- mode: boolean (nullable = true)
#  |-- name: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- release_date: date (nullable = true)
#  |-- speechiness: float (nullable = true)
#  |-- tempo: float (nullable = true)
#  |-- valence: float (nullable = true)
#  |-- year: integer (nullable = true)

# %% [markdown]
# # 3. BUSINESS QUESTIONS

# %% [markdown]
# ### 1 - Create a new dataframe reflecting the evolution for "Pop/Rock/Disco/Funk" music and the different Effects the music generates on people. Cluster the evolution in quarters of a century (25 years).

# %% [markdown]
# Business people have provided us the Genre-Tempo (Average BPM) correlation.
# - *Jazz/Reggae/Hip-Hop/Blues*: <108
# - *Pop/Rock/Disco/Funk*: 108-130
# - *Electro-House/Dubstep/Drum´n´n/Gabba*:>130

# %%
#"min(), max()" extract min and max values
#".groupBy" columns we want to group by.
#".agg" aggregations to apply to the different groups
from pyspark.sql.functions import min,max,avg

display(Markdown("**Pop/Rock/Disco/Funk EVOLUTION**"))

#Create a new column with the expected genre.
Genre_spotify = spotify\
    .withColumn("Genre", when(col("tempo")<108,"Jazz/Reggae/Hip-Hop/Blues")\
                        .when((col("tempo")>108) & (col("tempo")<=130),"Pop/Rock/Disco/Funk")\
                        .otherwise("Electro-House/Dubstep/Drum´n´n/Gabba"))\
    .cache()

#Create a new column with the CenturyQuarters.
#Filter the "Pop/Rock/Disco/Funk" genre.
#Aggregate the Effects on People.
Genre_spotify.where((col("Genre")=="Pop/Rock/Disco/Funk"))\
             .withColumn('CenturyQuarters',when(col('year')<=1946,"1921-1946")\
                                   .when(col('year')<=1971,"1946-1971")\
                                   .when(col('year')<=1996,"1971-1996")\
                                   .when(col('year')<=2021,"1996-2021")\
                                   .otherwise("unacceptable"))\
                                   .groupBy('CenturyQuarters')\
                                        .agg(avg('liveness').alias('avg_liveness'),\
                                            avg('danceability').alias('avg_danceability'),\
                                            avg('energy').alias('avg_energy'),\
                                            avg('valence').alias('avg_valence'),\
                                            avg('popularity').alias('avg_popularity'))\
        .toPandas()
# Out:
# **Pop/Rock/Disco/Funk EVOLUTION**
#   CenturyQuarters  avg_liveness  avg_danceability  avg_energy  avg_valence  \
# 0       1921-1946      0.220244          0.607480    0.289130     0.624788
# 1       1946-1971      0.211458          0.555406    0.388053     0.573950
# 2       1996-2021      0.192432          0.639720    0.651157     0.516799
# 3       1971-1996      0.205454          0.608996    0.603036     0.609978
#
#    avg_popularity
# 0        1.636378
# 1       18.900031
# 2       53.986777
# 3       38.059946

# %%
spotify.select('*').summary("count", "min", "25%", "75%", "max",'mean','stddev').toPandas()
# Out:
#   summary         acousticness  \
# 0   count               169909
# 1     min                  0.0
# 2     25%               0.0944
# 3     75%                0.888
# 4     max                0.996
# 5    mean    0.493213976149875
# 6  stddev  0.37662706233783233
#
#                                              artists         danceability  \
# 0                                             169909               169909
# 1  ["'In The Heights' Original Broadway Company",...                  0.0
# 2                                               None                0.417
# 3                                               None                0.667
# 4                                             ['黑豹']                0.988
# 5                                               None   0.5381497172015581
# 6                                               None  0.17534578204760803
#
#           duration_ms               energy             explicit  \
# 0              169909               169909               169909
# 1                5108                  0.0                    0
# 2              171040                0.263                    0
# 3              262943                 0.71                    0
# 4             5403500                  1.0                    1
# 5   231406.1589733328   0.4885931303603691  0.08486307376301432
# 6  121321.92321940271  0.26738993295713437  0.27867864925974417
#
#                        id     instrumentalness                 key  \
# 0                  169909               169909              169909
# 1  000G1xMMuwxNHmwVsBdtj1                  0.0                   0
# 2                    None                  0.0                   2
# 3                    None               0.0868                   8
# 4  7zzuPsjj9L3M7ikqGmjN0D                  1.0                  11
# 5                    None  0.16193714313891427   5.200519101401339
# 6                    None  0.30932888203837267  3.5152567984248693
#
#               liveness             loudness                 mode  \
# 0               169909               169909               169909
# 1                  0.0                -60.0                    0
# 2               0.0984               -14.47                    0
# 3                0.263               -7.119                    1
# 4                  1.0                3.855                    1
# 5  0.20669034936348246  -11.370289301920401   0.7085557563166165
# 6   0.1767964903942966   5.6667646295717695  0.45442899544073423
#
#                                   name          popularity  \
# 0                               169909              169909
# 1            !Que Vida! - Mono Version                   0
# 2                                 24.0                  12
# 3                               1980.0                  48
# 4  화려하지 않은 고백 Confession Is Not Flashy                 100
# 5                             Infinity   31.55660971461194
# 6                                  NaN  21.582613808557902
#
#          release_date          speechiness               tempo  \
# 0              169909               169909              169909
# 1                1921                  0.0                 0.0
# 2              1948.0               0.0349              93.519
# 3              1980.0               0.0754               135.7
# 4          2020-06-18                0.969             244.091
# 5  1963.7319876146244  0.09405769441288801  116.94801737400672
# 6  21.570826832323228  0.14993730259926946  30.726936654886917
#
#                valence                year
# 0               169909              169909
# 1                  0.0                1921
# 2                0.322                1957
# 3   0.7490000000000001                1999
# 4                  1.0                2020
# 5   0.5320951423473788  1977.2232312590857
# 6  0.26240763092035796  25.593167631762732

# %% [markdown]
# ### 2 - Spotify is exploring which are the TOP10 artists of the Century. To do so, Spotify Laboratory has created an specific formula with some weights to get the score (0/10) of a song depending of its characteristics.

# %% [markdown]
# |-- acousticness: Without Importance <br>
# |-- danceability: **2'3 WEIGHT** <br>
# |-- duration_ms: Without Importance <br>
# |-- energy: **2'2 WEIGHT** <br>
# |-- explicit: Without Importance <br>
# |-- instrumentalness: **1'7 WEIGHT** <br>
# |-- key: Without Importance <br>
# |-- liveness: **1'8WEIGHT** <br>
# |-- loudness: Without Importance <br>
# |-- mode: Without Importance <br>
# |-- popularity: Without Importance <br>
# |-- speechiness: Without Importance <br>
# |-- tempo: Without Importance <br>
# |-- valence: **2 WEIGHT** <br>

# %%
#Incorporate the magic formula.
spotify_score_song = \
    spotify.withColumn('SongScore', (col('danceability')*2.3)+\
                       (col('energy')*2.2)+\
                       (col('instrumentalness')*1.7)+\
                       (col('liveness')*1.8)+\
                       (col('valence')*2))\


#Create a new column with the classification
spotify_classification = \
    spotify_score_song.withColumn("Score_Class", when(col("SongScore")>6,"Master Piece")\
                                  .when((col("SongScore")>4) & (col("SongScore")<=6),"BooM")\
                                  .otherwise("Hit"))\
#Number of songs per Artist
totalSongsArtist = \
   spotify.groupBy("Artists")\
            .agg(count(lit(1)).alias("TotalSongsArtist"))

#Total Score per Artist
totalScoreArtist = \
   spotify_score_song.groupBy("Artists").sum('SongScore').alias("TotalScore")

###We go one step further and get the top artist per category.
#MULTILABEL AGGREGATION FUNCTION: Works with the pivot method.
display(Markdown("**Top 10 artist by music effect on People per category**"))
combinedDF = \
    spotify_classification\
        .join(totalScoreArtist,"Artists")\
        .join(totalSongsArtist,"Artists")\
        .groupBy('Artists')\
        .pivot('Score_class')\
        .sum('SongScore')\
        .orderBy(col("Master Piece").desc(), col("BooM").desc(), col("Hit").desc())\
        .limit(10)\
        .show()
# Out:
# **Top 10 artist by music effect on People per category**
# [Stage 250:=======================================>             (149 + 2) / 200]
# +--------------------+------------------+------------------+------------------+
# |             Artists|              BooM|               Hit|      Master Piece|
# +--------------------+------------------+------------------+------------------+
# |['Francisco Canaro']|3766.2471738190006| 339.1181750399999| 666.6690000000002|
# |['The Rolling Sto...|    1567.478463334|      351.00056298| 583.9042764999999|
# |    ['The Ventures']|224.99653880000005|19.967534999999998|340.46720000000005|
# |   ['Talking Heads']| 624.3107275039999|      54.090774591|     302.124889276|
# |  ['The Beach Boys']|1183.7382848040002| 625.0754569390001|227.51186677999996|
# | ['Michael Jackson']| 487.4030243919999|     104.402600076|219.97021203000003|
# |['Bob Marley & Th...|1184.7311648060002| 98.39069450600002|     180.338792233|
# |       ['New Order']|189.54113360300002|          10.83259|         177.22582|
# |['Orchestra Studi...|     572.443763666|     302.936123208|          161.3982|
# |    ['Depeche Mode']|     406.452319979|      68.484410164|       154.0625752|
# +--------------------+------------------+------------------+------------------+
# [Stage 250:==============================================>      (177 + 2) / 200]

# %% [markdown]
# ### 3- Raul is one of the most valuable customers inside Spotify, after several years of Sentiment Analysis we came to some conclusions about his ideal characteristics balance in music with a 95% of Confidence Level.
# ### By taking into account the following characteristics, Could you recommend Raul a List with 20 songs he would dance all night long?.
# ### In addition, Raul also prefers listening to music that was realease in the same season he is currently in because he beliefs that the vives and the energy are special. Could you recommend him another list?

# %% [markdown]
#  |-- acousticness: [0.4-1]<br>
#  |-- danceability: [0.3-0.8]<br>
#  |-- duration_ms: [100000-200000]<br>
#  |-- energy: [0.2-0.8] <br>
#  |-- explicit: 0 <br>
#  |-- instrumentalness: [0.3-0.8] <br>
#  |-- key: [5-10] <br>
#  |-- liveness: [0.1-0.5] <br>
#  |-- loudness: [(-15) - (-5)] <br>
#  |-- mode: 1 <br>
#  |-- popularity: [30-70] <br>
#  |-- speechiness: [0.0 - 0.30]<br>
#  |-- tempo: [19 - 150] <br>
#  |-- valence: [0.4-0.6]<br>

# %%
from pyspark.sql.functions import split
from pyspark.sql.functions import month,current_date

display(Markdown("**Plug in your headphones and enjoy! This list is specifically for you Raul**"))
Raul_list = spotify\
    .where((col('acousticness')>0.4)&
           (col("acousticness")<1)&
           (col('danceability')>0.3)&\
           (col("danceability")<0.8)&\
           (col('duration_ms')>100000)&\
           (col("acousticness")<200000)&\
           (col('energy')>0.2)&\
           (col("energy")<0.8)&\
           (col("explicit")==0)&\
           (col("instrumentalness")>0.3)&\
           (col("instrumentalness")<0.8)&\
           (col("key")>5)&\
           (col("key")<10)&\
           (col("liveness")>0.1)&\
           (col("liveness")<0.5)&\
           (col("loudness")>(-15))&\
           (col("loudness")<(-5))&\
           (col("mode")==1)&\
           (col("popularity")>30)&\
           (col("popularity")<70)&\
           (col("speechiness")>0)&\
           (col("speechiness")<0.3)&\
           (col("tempo")>90)&\
           (col("tempo")<150)&\
           (col("valence")>0.4)&\
           (col("valence")<0.6))\
    .select('name','artists')\
    .orderBy('popularity')\
    .limit(20).show()

#"split" to separate between months, days, years.. and "getItem" to organize it in different columns
#"month"extracts the month from "current_date" and include it as a column
Spotify_date = spotify\
    .withColumn("split_date",split("release_date","-"or"/"))\
    .withColumn('year',col("split_date").getItem(0))\
    .withColumn('month',col("split_date").getItem(1))\
    .withColumn('day',col("split_date").getItem(2))\
    .withColumn('actual_month',month(current_date()))\
    .select('name','artists','actual_month',"release_date","day","month","year")\

display(Markdown("**Raul!, this list is designed for listening during this Season**"))

#Assign the season to the current date and the one in which the song was realeased.
#Select only the songs where the released_season is the same as the one we are in.
spotify_seasons = \
  Spotify_date \
     .withColumn('Season_release', when((col('month')>=12) | ((col('month')<=2)),"Winter")
         .when((col('month')>=3) & ((col('month')<=5)),"Spring")\
         .when((col('month')>=6) & ((col('month')<=8)),"Summer")\
         .when((col('month')>=9) & ((col('month')<=11)),"Autumn")\
         .otherwise("unacceptable"))\
     .withColumn('actual_season', when((col('actual_month')>=12) | ((col('actual_month')<=2)),"Winter")
         .when((col('actual_month')>=3) & ((col('actual_month')<=5)),"Spring")\
         .when((col('actual_month')>=6) & ((col('actual_month')<=8)),"Summer")\
         .when((col('actual_month')>=9) & ((col('actual_month')<=11)),"Autumn")\
         .otherwise("unacceptable"))\
     .where((col("actual_season"))==(col('Season_release')))\
     .select('name','artists',"release_date","month",'Season_release','actual_season')\
     .orderBy('popularity')\
     .show()
# Out:
# **Plug in your headphones and enjoy! This list is specificly for you Raul**
# +--------------------+--------------------+
# |                name|             artists|
# +--------------------+--------------------+
# |    What Now My Love|['Herb Alpert & T...|
# |        Emily's Song| ['The Moody Blues']|
# |             Godsend|  ['Beat Happening']|
# |Nothing but Time ...|  ['Jackson Browne']|
# |Pharaohs - Single...| ['Tears For Fears']|
# |     In My Own Dream|    ['Karen Dalton']|
# |Momma Miss Americ...|  ['Paul McCartney']|
# |       Juke Box Mama|       ['Link Wray']|
# |           All Of Me|['Oscar Peterson ...|
# |            Ever New|['Beverly Glenn-C...|
# |              Dreams|['The Allman Brot...|
# |             Pilgrim|['Steve Earle', '...|
# |       Strictly Rule|         ['Vetiver']|
# |               Jingo|         ['Santana']|
# |           Oh I Wept|            ['Free']|
# |        Drivin' on 9|    ['The Breeders']|
# |      Goin' Out West|       ['Tom Waits']|
# |She's Really All ...|     ['Mac DeMarco']|
# |            My Jinji|['Sunset Rollerco...|
# |You Might Be Slee...|['Jakob Ogawa', '...|
# +--------------------+--------------------+
# **Raul!, this list is designed for this Season**
# +--------------------+--------------------+------------+-----+--------------+-------------+
# |                name|             artists|release_date|month|Season_release|actual_season|
# +--------------------+--------------------+------------+-----+--------------+-------------+
# |Beba Mia - Instru...|['Francisco Canaro']|  1927-09-11|   09|        Autumn|       Autumn|
# |Pobre Canillita -...|['Francisco Canar...|  1928-09-24|   09|        Autumn|       Autumn|
# |Alfredo - Instrum...|['Francisco Canaro']|  1927-09-16|   09|        Autumn|       Autumn|
# |Jinetazo - Remast...|['Francisco Canar...|  1927-09-04|   09|        Autumn|       Autumn|
# |Caricias De Mujer...|['Francisco Canaro']|  1927-09-05|   09|        Autumn|       Autumn|
# |Palo Verde - Inst...|['Francisco Canaro']|  1927-09-06|   09|        Autumn|       Autumn|
# |Retirao - Instrum...|['Francisco Canaro']|  1927-09-04|   09|        Autumn|       Autumn|
# |Noche de Reyes - ...|['Francisco Canar...|  1927-09-11|   09|        Autumn|       Autumn|
# |El Mal Que Me Hic...|['Francisco Canar...|  1927-09-04|   09|        Autumn|       Autumn|
# |Patroncita - Inst...|['Francisco Canaro']|  1927-09-04|   09|        Autumn|       Autumn|
# |Mina Bacana - Ins...|['Francisco Canaro']|  1927-09-04|   09|        Autumn|       Autumn|
# |Madrecita Yo Me M...|['Francisco Canaro']|  1927-09-16|   09|        Autumn|       Autumn|
# |Leguisamo Solo - ...|['Francisco Canaro']|  1927-09-11|   09|        Autumn|       Autumn|
# |El Hijo de Julián...|['Francisco Canaro']|  1927-09-17|   09|        Autumn|       Autumn|
# |Río De Oro - Inst...|['Francisco Canaro']|  1927-09-05|   09|        Autumn|       Autumn|
# |Alhaja Falsa - Re...|['Francisco Canar...|  1927-09-17|   09|        Autumn|       Autumn|
# |Pebeta elegante -...|['Francisco Canaro']|  1928-09-25|   09|        Autumn|       Autumn|
# |Por Mi Honor - In...|['Francisco Canaro']|  1927-09-17|   09|        Autumn|       Autumn|
# |Fuego Y Ceniza - ...|['Francisco Canaro']|  1927-09-05|   09|        Autumn|       Autumn|
# |Entre Sueños - Re...|['Francisco Canar...|  1928-09-25|   09|        Autumn|       Autumn|
# +--------------------+--------------------+------------+-----+--------------+-------------+
# only showing top 20 rows

# %% [markdown]
# # 4. FREE STYLE & SKETCHES

# %%
from pyspark.sql.functions import lit
print ("Most and least frequent occurrences for FlightNum, TailNum, Origin and Dest columns:")
group_artist_songs = spotify.groupBy("artists").agg(count(lit(1)).alias("artists_songs"))

mostFreqArtist   = group_artist_songs.orderBy(col("artists_songs").desc()).first()

display(Markdown("""
| %s | 
|----|
| %s | 
""" % ("mostFreqArtist", \
       "%s (%d occurrences)" % (mostFreqArtist["artists"],mostFreqArtist["artists_songs"]))))
# Out:
# Most and least frequent occurrences for FlightNum, TailNum, Origin and Dest columns:
# [Stage 132:============================================>        (168 + 2) / 200]
# | mostFreqArtist |
# |----|
# | ['Эрнест Хемингуэй'] (1215 occurrences) |

# %%
#"col_name[position]" using operator to access the elemnts of the array
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import split,col
from pyspark.sql import Row

spotify.withColumn("split_date",split("release_date","-"or"/") )\
        .withColumn('year',expr("split_date[0]"))\
        .withColumn('month',expr("split_date[1]"))\
        .withColumn('day',expr("split_date[2]"))\
        .select("release_date","day","month","year")\
        .show()
# Out:
# +------------+----+-----+----+
# |release_date| day|month|year|
# +------------+----+-----+----+
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-09-25|  25|   09|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-10-03|  03|   10|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-01-01|  01|   01|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-09-16|  16|   09|1928|
# |        1928|null| null|1928|
# |  1928-09-17|  17|   09|1928|
# +------------+----+-----+----+
# only showing top 20 rows

# %%
#Fields in a row can be accessed in this two ways.
#Way1
spotify.first().acousticness
# Out:
# 0.995

# %%
#"corr(col1,col2)" returns a new column for the Pearson Correlation Coefficient
from pyspark.sql.functions import col, corr
spotify.select(corr(col('year'),col('popularity'))).show()
# Out:
# +----------------------+
# |corr(year, popularity)|
# +----------------------+
# |    0.8807241644750249|
# +----------------------+

# %%
#".when(condition,value)", equivalent to the IF function, returns one of multiple results.
#".otherwise()" equivalent to ELSE function
#"substring(col,position, number of characters)" Take the selected test from one column

from pyspark.sql.functions import substring
from pyspark.sql.functions import col, when


spotify.withColumn('CenturyQuarters',when(col('year')>1946,"1921-1946")\
                                   .when(col('year')<=1971,"1946-1971")\
                                   .when(col('year')<=1996,"1971-1996")\
                                   .when(col('year')<=2021,"1996-1921")\
                                   .otherwise("unacceptable"))\
    .select(col('CenturyQuarters')).distinct()\
    .show()
# Out:
# +---------------+
# |CenturyQuarters|
# +---------------+
# |      1921-1946|
# |      1946-1971|
# |      1996-1921|
# |      1971-1996|
# +---------------+

# %%
#Way2
spotify.first()['acousticness']
# Out:
# 0.995

# %%
#".show(num,truncate,vertical)" returns content as a text.
spotify.show(3,5, True)
# Out:
# -RECORD 0-----------------
#  acousticness     | 0.995
#  artists          | ['...
#  danceability     | 0.708
#  duration_ms      | 15...
#  energy           | 0.195
#  explicit         | 0
#  id               | 6K...
#  instrumentalness | 0.563
#  key              | 10
#  liveness         | 0.151
#  loudness         | -1...
#  mode             | 1
#  name             | Si...
#  popularity       | 0
#  release_date     | 1928
#  speechiness      | 0....
#  tempo            | 11...
#  valence          | 0.779
#  year             | 1928
# -RECORD 1-----------------
#  acousticness     | 0.994
#  artists          | ['...
#  danceability     | 0.379
#  duration_ms      | 28...
#  energy           | 0....
#  explicit         | 0
#  id               | 6K...
#  instrumentalness | 0.901
#  key              | 8
#  liveness         | 0....
#  loudness         | -2...
#  mode             | 1
#  name             | Fa...
#  popularity       | 0
#  release_date     | 1928
#  speechiness      | 0....
#  tempo            | 83...
#  valence          | 0....
#  year             | 1928
# -RECORD 2-----------------
#  acousticness     | 0.604
#  artists          | ['...
#  danceability     | 0....
#  duration_ms      | 10...
#  energy           | 0.22
#  explicit         | 0
#  id               | 6L...
#  instrumentalness | 0.0
#  key              | 5
#  liveness         | 0.119
#  loudness         | -1...
#  mode             | 0
#  name             | Ch...
#  popularity       | 0
#  release_date     | 1928
#  speechiness      | 0.929
#  tempo            | 10...
#  valence          | 0.88
#  year             | 1928
# only showing top 3 rows

# %%
#".collect" returns contents as a list .
spotify.collect()
# Out:
# [Row(acousticness=0.995, artists="['Carl Woitschach']", danceability=0.708, duration_ms=158648, energy=0.195, explicit=0, id='6KbQ3uYMLKb5jDxLF7wYDD', instrumentalness=0.563, key=10, liveness=0.151, loudness=-12.428, mode=1, name='Singende Bataillone 1. Teil', popularity=0, release_date='1928', speechiness=0.0506, tempo=118.469, valence=0.779, year=1928),
#  Row(acousticness=0.994, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.379, duration_ms=282133, energy=0.0135, explicit=0, id='6KuQTIu1KoTTkLXKrwlLPV', instrumentalness=0.901, key=8, liveness=0.0763, loudness=-28.454, mode=1, name='Fantasiestücke, Op. 111: Più tosto lento', popularity=0, release_date='1928', speechiness=0.0462, tempo=83.97200000000002, valence=0.0767, year=1928),
#  Row(acousticness=0.604, artists="['Seweryn Goszczyński']", danceability=0.7490000000000001, duration_ms=104300, energy=0.22, explicit=0, id='6L63VW0PibdM1HDSBoqnoM', instrumentalness=0.0, key=5, liveness=0.119, loudness=-19.924, mode=0, name='Chapter 1.18 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.929, tempo=107.177, valence=0.88, year=1928),
#  Row(acousticness=0.995, artists="['Francisco Canaro']", danceability=0.7809999999999999, duration_ms=180760, energy=0.13, explicit=0, id='6M94FkXd15sOAOQYRnWPN8', instrumentalness=0.887, key=1, liveness=0.111, loudness=-14.734000000000002, mode=0, name='Bebamos Juntos - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-25', speechiness=0.0926, tempo=108.003, valence=0.72, year=1928),
#  Row(acousticness=0.99, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.21, duration_ms=687733, energy=0.204, explicit=0, id='6N6tiFZ9vLTSOIxkj8qKrd', instrumentalness=0.908, key=11, liveness=0.098, loudness=-16.829, mode=1, name='Polonaise-Fantaisie in A-Flat Major, Op. 61', popularity=1, release_date='1928', speechiness=0.0424, tempo=62.149, valence=0.0693, year=1928),
#  Row(acousticness=0.995, artists="['Felix Mendelssohn', 'Vladimir Horowitz']", danceability=0.424, duration_ms=352600, energy=0.12, explicit=0, id='6NxAf7M8DNHOBTmEd3JSO5', instrumentalness=0.911, key=6, liveness=0.0915, loudness=-19.242, mode=0, name='Scherzo a capriccio: Presto', popularity=0, release_date='1928', speechiness=0.0593, tempo=63.521, valence=0.266, year=1928),
#  Row(acousticness=0.956, artists="['Franz Liszt', 'Vladimir Horowitz']", danceability=0.444, duration_ms=136627, energy=0.197, explicit=0, id='6O0puPuyrxPjDTHDUgsWI7', instrumentalness=0.435, key=11, liveness=0.0744, loudness=-17.226, mode=1, name='Valse oubliée No. 1 in F-Sharp Major, S. 215/1', popularity=0, release_date='1928', speechiness=0.04, tempo=80.495, valence=0.305, year=1928),
#  Row(acousticness=0.988, artists="['Carl Woitschach']", danceability=0.555, duration_ms=153967, energy=0.421, explicit=0, id='6OJjveoYwJdIt76y0Pxpxw', instrumentalness=0.836, key=1, liveness=0.105, loudness=-9.878, mode=1, name='Per aspera ad astra', popularity=0, release_date='1928', speechiness=0.0474, tempo=123.31, valence=0.857, year=1928),
#  Row(acousticness=0.995, artists="['Francisco Canaro', 'Charlo']", danceability=0.6829999999999999, duration_ms=162493, energy=0.207, explicit=0, id='6OaJ8Bh7lsBeYoBmwmo2nh', instrumentalness=0.206, key=9, liveness=0.337, loudness=-9.801, mode=0, name='Moneda Corriente - Remasterizado', popularity=0, release_date='1928-10-03', speechiness=0.127, tempo=119.833, valence=0.493, year=1928),
#  Row(acousticness=0.846, artists="['Seweryn Goszczyński']", danceability=0.674, duration_ms=111600, energy=0.205, explicit=0, id='6PrZexNb16cabXR8Q418Xc', instrumentalness=0.0, key=9, liveness=0.17, loudness=-20.119, mode=1, name='Chapter 1.3 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.954, tempo=81.249, valence=0.759, year=1928),
#  Row(acousticness=0.994, artists="['Sergei Rachmaninoff', 'Vladimir Horowitz']", danceability=0.376, duration_ms=590293, energy=0.0719, explicit=0, id='6QBInZBkQNIQYU9gGzT5l4', instrumentalness=0.883, key=10, liveness=0.196, loudness=-21.849, mode=0, name='Piano Sonata No. 2 in B-Flat Minor, Op. 36: I. Allegro agitato - Meno mosso', popularity=0, release_date='1928', speechiness=0.0352, tempo=141.39, valence=0.0393, year=1928),
#  Row(acousticness=0.989, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.17, duration_ms=85133, energy=0.0823, explicit=0, id='6QIONtzbQCbnmWNwn0H1yT', instrumentalness=0.911, key=10, liveness=0.0962, loudness=-30.107, mode=0, name='Piano Sonata No. 2, Op. 35: IV. Finale. Presto', popularity=1, release_date='1928', speechiness=0.0317, tempo=85.98899999999998, valence=0.34600000000000003, year=1928),
#  Row(acousticness=0.99, artists="['Samuel Barber', 'Vladimir Horowitz']", danceability=0.359, duration_ms=338333, energy=0.0435, explicit=0, id='6QgdUySTRGVkNo3KwbHpK3', instrumentalness=0.899, key=7, liveness=0.109, loudness=-20.858, mode=1, name='Piano Sonata in E-Flat Minor, Op. 26: III. Adagio mesto', popularity=0, release_date='1928', speechiness=0.0424, tempo=96.645, valence=0.042, year=1928),
#  Row(acousticness=0.992, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.311, duration_ms=167333, energy=0.0107, explicit=0, id='6RvSNoCPBZeTR2LyGvdJOw', instrumentalness=0.883, key=5, liveness=0.0954, loudness=-35.648, mode=1, name='Nachtstücke, Op. 23: No. 4 in F', popularity=0, release_date='1928', speechiness=0.0556, tempo=78.98, valence=0.21600000000000005, year=1928),
#  Row(acousticness=0.977, artists="['Ludwig van Beethoven', 'Staatskapelle Berlin', 'Richard Strauss']", danceability=0.335, duration_ms=276563, energy=0.105, explicit=0, id='6Rwn56jcC0TdGQzbRl7NGw', instrumentalness=0.84, key=5, liveness=0.231, loudness=-16.049, mode=0, name='Symphony No. 5 in C Minor, Op. 67: 3. Allegro', popularity=0, release_date='1928-01-01', speechiness=0.0716, tempo=80.204, valence=0.406, year=1928),
#  Row(acousticness=0.991, artists="['George Butterworth', 'John Cameron']", danceability=0.319, duration_ms=184840, energy=0.00593, explicit=0, id='6Sdpmree8xpGWaedACPMlP', instrumentalness=6.35e-05, key=7, liveness=0.0691, loudness=-25.789, mode=0, name='A Shropshire Lad: Is My Team Ploughing?', popularity=0, release_date='1928', speechiness=0.051, tempo=79.831, valence=0.16899999999999998, year=1928),
#  Row(acousticness=0.996, artists="['Alexander Scriabin', 'Vladimir Horowitz']", danceability=0.319, duration_ms=326067, energy=0.155, explicit=0, id='6T0mZB7p3qzOifdXZ3Su9P', instrumentalness=0.917, key=4, liveness=0.126, loudness=-18.728, mode=1, name='Sonata No. 3, Op. 23 in F-Sharp Minor: IV. Presto con fuoco; Meno mosso', popularity=0, release_date='1928', speechiness=0.036000000000000004, tempo=66.947, valence=0.0488, year=1928),
#  Row(acousticness=0.994, artists="['Francisco Canaro', 'Luis Scalon']", danceability=0.787, duration_ms=167107, energy=0.156, explicit=0, id='6TFuAErGpJ9FpxQQ1HC8nM', instrumentalness=0.659, key=4, liveness=0.11, loudness=-14.056, mode=0, name='Invocación al Tango - Remasterizado', popularity=0, release_date='1928-09-16', speechiness=0.157, tempo=117.167, valence=0.8490000000000001, year=1928),
#  Row(acousticness=0.993, artists="['Thomas Arne', 'John Heddle Nash']", danceability=0.569, duration_ms=122533, energy=0.15, explicit=0, id='6UUfiNT82MWBNnmsE2ZNWf', instrumentalness=0.0015, key=5, liveness=0.106, loudness=-15.238, mode=1, name='Where the Bee Sucks', popularity=0, release_date='1928', speechiness=0.0474, tempo=76.93, valence=0.596, year=1928),
#  Row(acousticness=0.992, artists="['Francisco Canaro']", danceability=0.763, duration_ms=173707, energy=0.132, explicit=0, id='6Ukl7n0q3Cjd0Og8uBmVeP', instrumentalness=0.0693, key=4, liveness=0.112, loudness=-13.002, mode=1, name='Tendrás Que Llorar Conmigo - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-17', speechiness=0.0886, tempo=111.679, valence=0.8320000000000001, year=1928),
#  Row(acousticness=0.993, artists="['Moritz Moszkowski', 'Vladimir Horowitz']", danceability=0.35200000000000004, duration_ms=80800, energy=0.132, explicit=0, id='6UxGTlqovmrBV4SKAsoz0A', instrumentalness=0.966, key=8, liveness=0.425, loudness=-23.202, mode=1, name='Etude in A-Flat, Op. 72, No. 11', popularity=0, release_date='1928', speechiness=0.0381, tempo=74.737, valence=0.6609999999999999, year=1928),
#  Row(acousticness=0.99, artists="['Francisco Canaro']", danceability=0.833, duration_ms=176000, energy=0.132, explicit=0, id='6VGWQU6XIXshFT288CoLrk', instrumentalness=0.0005679999999999999, key=1, liveness=0.0957, loudness=-11.130999999999998, mode=1, name='Quisiste Cachar un Gil - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-20', speechiness=0.295, tempo=121.779, valence=0.568, year=1928),
#  Row(acousticness=0.975, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.277, duration_ms=245440, energy=0.09, explicit=0, id='6VUm7Dg5sufmG01IYcoJE3', instrumentalness=0.949, key=7, liveness=0.125, loudness=-26.188, mode=1, name='Andante spianato in E-Flat Major, Op. 22', popularity=0, release_date='1928', speechiness=0.0316, tempo=105.031, valence=0.168, year=1928),
#  Row(acousticness=0.99, artists="['Francisco Canaro']", danceability=0.8109999999999999, duration_ms=169720, energy=0.175, explicit=0, id='6VqUdRHLlFMXmN4plGWSMA', instrumentalness=0.841, key=9, liveness=0.13, loudness=-13.639, mode=1, name='La Recova - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-16', speechiness=0.0712, tempo=115.212, valence=0.933, year=1928),
#  Row(acousticness=0.988, artists="['Francisco Canaro', 'Charlo']", danceability=0.6990000000000001, duration_ms=166000, energy=0.221, explicit=0, id='6W7iUeL4W0WVIF1BEOCswF', instrumentalness=0.0725, key=11, liveness=0.142, loudness=-12.228, mode=1, name='El Espejito - Remasterizado', popularity=0, release_date='1928-09-20', speechiness=0.115, tempo=117.899, valence=0.782, year=1928),
#  Row(acousticness=0.988, artists="['Roger Quilter', 'John Heddle Nash']", danceability=0.54, duration_ms=152600, energy=0.102, explicit=0, id='6WBXyRc3ynwvRHiBWudVLo', instrumentalness=2.13e-06, key=4, liveness=0.0819, loudness=-18.555, mode=1, name='It Was a Lover and His Lass', popularity=0, release_date='1928', speechiness=0.0792, tempo=73.516, valence=0.433, year=1928),
#  Row(acousticness=0.99, artists="['Hafız Yaşar']", danceability=0.569, duration_ms=162197, energy=0.327, explicit=0, id='6WFYaPHg3P8jQuh7x9YKYZ', instrumentalness=0.947, key=7, liveness=0.134, loudness=-13.622, mode=1, name='Kız Saçların', popularity=0, release_date='1928-05-07', speechiness=0.0499, tempo=82.742, valence=0.562, year=1928),
#  Row(acousticness=0.991, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.38, duration_ms=505920, energy=0.119, explicit=0, id='6WRmg6x1bYjHxzeMCfKguB', instrumentalness=0.89, key=11, liveness=0.0601, loudness=-21.255, mode=1, name='Scherzo No. 1 in B Minor, Op. 20', popularity=0, release_date='1928', speechiness=0.0389, tempo=132.005, valence=0.18, year=1928),
#  Row(acousticness=0.993, artists="['Muzio Clementi', 'Vladimir Horowitz']", danceability=0.28, duration_ms=251960, energy=0.0436, explicit=0, id='6WSYfri77xoUvXLg3WTdLF', instrumentalness=0.885, key=8, liveness=0.0865, loudness=-25.958, mode=1, name='Sonata, Op. 14, No. 3 in F Minor: I. Allegro agitato', popularity=0, release_date='1928', speechiness=0.0393, tempo=81.07600000000002, valence=0.182, year=1928),
#  Row(acousticness=0.6859999999999999, artists="['Seweryn Goszczyński']", danceability=0.715, duration_ms=102200, energy=0.22, explicit=0, id='6XD6qJykJ91uC9AYb84ZeY', instrumentalness=0.0, key=2, liveness=0.206, loudness=-19.788, mode=1, name='Chapter 4.12 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.948, tempo=113.214, valence=0.545, year=1928),
#  Row(acousticness=0.995, artists="['Francisco Canaro', 'Charlo']", danceability=0.767, duration_ms=177507, energy=0.23, explicit=0, id='6XbXjlJZxRZslzXDh115DL', instrumentalness=0.605, key=2, liveness=0.133, loudness=-10.728, mode=1, name='Venite Conmigo - Remasterizado', popularity=0, release_date='1928-09-25', speechiness=0.199, tempo=119.985, valence=0.868, year=1928),
#  Row(acousticness=0.995, artists="['Ignacio Corsini']", danceability=0.531, duration_ms=159107, energy=0.124, explicit=0, id='6XoyWGdCJwFaJV1Pnmphwr', instrumentalness=0.0168, key=2, liveness=0.118, loudness=-23.243, mode=1, name='Por una Mujer - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.0711, tempo=101.902, valence=0.555, year=1928),
#  Row(acousticness=0.422, artists="['Shungi Music Crew']", danceability=0.662, duration_ms=372962, energy=0.606, explicit=0, id='6XxKNIhZQsW1A5Sg6O32Is', instrumentalness=0.915, key=7, liveness=0.0594, loudness=-7.026, mode=0, name='Loving You', popularity=0, release_date='1928-08-20', speechiness=0.0376, tempo=111.999, valence=0.645, year=1928),
#  Row(acousticness=0.987, artists="['George Butterworth', 'John Cameron']", danceability=0.238, duration_ms=173293, energy=0.0324, explicit=0, id='6Z6DJ8L7WMy2WHbXe3jR9I', instrumentalness=0.000986, key=7, liveness=0.112, loudness=-24.361, mode=0, name='A Shropshire Lad: Oh Fair Enough are Sky and Plain', popularity=0, release_date='1928', speechiness=0.0541, tempo=172.321, valence=0.0379, year=1928),
#  Row(acousticness=0.983, artists="['Ignacio Corsini']", danceability=0.6679999999999999, duration_ms=151840, energy=0.261, explicit=0, id='6ZSXaYQBOPDDmKeqaOfBa2', instrumentalness=0.0232, key=7, liveness=0.122, loudness=-16.91, mode=0, name='Abuelita - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.101, tempo=120.553, valence=0.7020000000000001, year=1928),
#  Row(acousticness=0.989, artists="['Perchicot']", danceability=0.769, duration_ms=140267, energy=0.442, explicit=0, id='6ZWi1fuonJCUlt4p6o9Uzs', instrumentalness=1.27e-06, key=2, liveness=0.16699999999999998, loudness=-12.697, mode=0, name='La Noce À Rebecca', popularity=0, release_date='1928', speechiness=0.273, tempo=132.125, valence=0.934, year=1928),
#  Row(acousticness=0.994, artists="['Francisco Canaro', 'Charlo']", danceability=0.8009999999999999, duration_ms=166493, energy=0.113, explicit=0, id='6aBzlB3FTioN5vCTfdswr8', instrumentalness=0.206, key=4, liveness=0.129, loudness=-12.147, mode=1, name='Por Esta Cruz - Remasterizado', popularity=0, release_date='1928-09-20', speechiness=0.0837, tempo=117.063, valence=0.672, year=1928),
#  Row(acousticness=0.994, artists="['Francisco Canaro']", danceability=0.8540000000000001, duration_ms=200213, energy=0.151, explicit=0, id='6aNewFey3lEHDerGgy3rYN', instrumentalness=0.371, key=4, liveness=0.159, loudness=-11.163, mode=0, name='Che Bouhier - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-16', speechiness=0.13699999999999998, tempo=110.331, valence=0.7809999999999999, year=1928),
#  Row(acousticness=0.708, artists="['Seweryn Goszczyński']", danceability=0.677, duration_ms=95900, energy=0.204, explicit=0, id='6aXTusFB0Ycjmt9TXr2cfK', instrumentalness=0.0, key=1, liveness=0.104, loudness=-20.024, mode=0, name='Chapter 4.10 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.957, tempo=84.82600000000002, valence=0.667, year=1928),
#  Row(acousticness=0.777, artists="['Seweryn Goszczyński']", danceability=0.738, duration_ms=139100, energy=0.282, explicit=0, id='6bKJYhoaWIohnhspidbdW7', instrumentalness=0.0, key=1, liveness=0.29, loudness=-16.555999999999994, mode=1, name='Chapter 2.11 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.952, tempo=140.612, valence=0.703, year=1928),
#  Row(acousticness=0.977, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.305, duration_ms=215267, energy=0.083, explicit=0, id='6duqhjENDYbR2Q4Hpogh9M', instrumentalness=0.6970000000000001, key=6, liveness=0.231, loudness=-20.895, mode=1, name='Nocturne in F-Sharp Major, Op. 15, No. 2', popularity=1, release_date='1928', speechiness=0.0331, tempo=80.622, valence=0.0479, year=1928),
#  Row(acousticness=0.993, artists="['Dmitry Kabalevsky', 'Vladimir Horowitz']", danceability=0.3720000000000001, duration_ms=285133, energy=0.0945, explicit=0, id='6h6ShFPagQGy48KSFd8BU9', instrumentalness=0.941, key=10, liveness=0.189, loudness=-22.709, mode=0, name='Sonata No. 3, Op. 46: II. Andante cantabile', popularity=0, release_date='1928', speechiness=0.0317, tempo=59.217, valence=0.0791, year=1928),
#  Row(acousticness=0.99, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.337, duration_ms=333907, energy=0.0699, explicit=0, id='6hUMURfCaJ6JB8EWL1ZLr7', instrumentalness=0.903, key=5, liveness=0.106, loudness=-23.806, mode=0, name='Nocturne F Minor, Op. 55, No. 1', popularity=2, release_date='1928', speechiness=0.0322, tempo=72.133, valence=0.135, year=1928),
#  Row(acousticness=0.995, artists="['Francisco Canaro']", danceability=0.7290000000000001, duration_ms=174720, energy=0.191, explicit=0, id='6hcPbniXegOud4FNv8Efxz', instrumentalness=0.455, key=4, liveness=0.103, loudness=-15.313, mode=0, name='Timbero - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-17', speechiness=0.108, tempo=112.565, valence=0.902, year=1928),
#  Row(acousticness=0.826, artists="['Seweryn Goszczyński']", danceability=0.726, duration_ms=108800, energy=0.249, explicit=0, id='6i3IWozMMPQXtD5W1klS0n', instrumentalness=0.0, key=9, liveness=0.173, loudness=-16.82, mode=0, name='Chapter 3.4 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.952, tempo=112.379, valence=0.5589999999999999, year=1928),
#  Row(acousticness=0.662, artists="['Seweryn Goszczyński']", danceability=0.631, duration_ms=109900, energy=0.23, explicit=0, id='6i7kom9nwTggWaYQAW9puH', instrumentalness=0.0, key=1, liveness=0.145, loudness=-19.213, mode=0, name='Chapter 1.13 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.959, tempo=83.40100000000002, valence=0.595, year=1928),
#  Row(acousticness=0.985, artists="['Francisco Canaro']", danceability=0.81, duration_ms=169160, energy=0.3, explicit=0, id='6iInEwECoC9ZX8uPDRjyft', instrumentalness=0.0008849999999999998, key=4, liveness=0.13, loudness=-9.702, mode=1, name='Mariposa de Cabaret - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-25', speechiness=0.289, tempo=115.648, valence=0.8059999999999999, year=1928),
#  Row(acousticness=0.985, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.355, duration_ms=138013, energy=0.0452, explicit=0, id='6j8nMxm9yFxN3Mdodm9tEl', instrumentalness=0.825, key=1, liveness=0.153, loudness=-24.125, mode=1, name='Mazurka in F Minor, Op. 7, No. 3', popularity=2, release_date='1928', speechiness=0.0329, tempo=84.551, valence=0.276, year=1928),
#  Row(acousticness=0.461, artists="['Shungi Music Crew']", danceability=0.733, duration_ms=369721, energy=0.613, explicit=0, id='6jIUK38SalSc8jYFLW4FYv', instrumentalness=0.951, key=7, liveness=0.122, loudness=-8.749, mode=1, name='Rumours', popularity=0, release_date='1928-08-20', speechiness=0.0383, tempo=123.019, valence=0.26, year=1928),
#  Row(acousticness=0.993, artists="['Franz Liszt', 'Vladimir Horowitz']", danceability=0.303, duration_ms=491333, energy=0.226, explicit=0, id='6jm4s7lONpJRXumjV6WH23', instrumentalness=0.826, key=3, liveness=0.119, loudness=-21.483, mode=1, name='Danse macabre, S. 555 (after Camille Saint-Saens)', popularity=0, release_date='1928', speechiness=0.0444, tempo=67.013, valence=0.146, year=1928),
#  Row(acousticness=0.995, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.319, duration_ms=118093, energy=0.00217, explicit=0, id='6jpxi5YTFfquMKm7HLS0fW', instrumentalness=0.937, key=10, liveness=0.0791, loudness=-36.905, mode=1, name='Humoreske, Op. 20: Einfach', popularity=0, release_date='1928', speechiness=0.0412, tempo=78.505, valence=0.229, year=1928),
#  Row(acousticness=0.992, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.468, duration_ms=158973, energy=0.0184, explicit=0, id='6k3zky8VRvpPo9T5dqWbKS', instrumentalness=0.912, key=10, liveness=0.103, loudness=-27.785, mode=1, name='Humoreske, Op. 20: Innig', popularity=0, release_date='1928', speechiness=0.0447, tempo=59.38, valence=0.235, year=1928),
#  Row(acousticness=0.992, artists="['Ignacio Corsini']", danceability=0.698, duration_ms=168400, energy=0.192, explicit=0, id='6k6oWqs8cZnnjY38LdP08T', instrumentalness=0.00577, key=2, liveness=0.243, loudness=-17.343, mode=1, name='La Carreta - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.128, tempo=78.218, valence=0.6809999999999999, year=1928),
#  Row(acousticness=0.993, artists="['Francisco Canaro', 'Charlo']", danceability=0.836, duration_ms=194000, energy=0.207, explicit=0, id='6kfj3G8mZQH4n530vJen6L', instrumentalness=0.522, key=7, liveness=0.321, loudness=-9.54, mode=1, name='Dentra, No Llores - Remasterizado', popularity=0, release_date='1928-10-03', speechiness=0.152, tempo=112.369, valence=0.595, year=1928),
#  Row(acousticness=0.992, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.233, duration_ms=519933, energy=0.113, explicit=0, id='6l4zbFqen97rgCxmq9LWgK', instrumentalness=0.879, key=1, liveness=0.161, loudness=-18.276, mode=1, name='Barcarolle, Op. 60', popularity=0, release_date='1928', speechiness=0.0397, tempo=64.082, valence=0.0642, year=1928),
#  Row(acousticness=0.993, artists="['Paul Whiteman']", danceability=0.6409999999999999, duration_ms=161587, energy=0.192, explicit=0, id='6m2U5lsHxlDvCUl6aZzCLO', instrumentalness=0.5, key=3, liveness=0.593, loudness=-15.905, mode=1, name="I'd Rather Cry Over You", popularity=0, release_date='1928', speechiness=0.04, tempo=106.052, valence=0.7040000000000001, year=1928),
#  Row(acousticness=0.995, artists="['Francisco Canaro', 'Charlo']", danceability=0.461, duration_ms=204867, energy=0.195, explicit=0, id='6mUmlFMnIKz3m8rIDnzwd0', instrumentalness=0.8859999999999999, key=10, liveness=0.0969, loudness=-15.059, mode=1, name='En un Pueblito de España - Remasterizado', popularity=0, release_date='1928-09-21', speechiness=0.0609, tempo=76.419, valence=0.8440000000000001, year=1928),
#  Row(acousticness=0.989, artists="['Muzio Clementi', 'Vladimir Horowitz']", danceability=0.222, duration_ms=351000, energy=0.0113, explicit=0, id='6mUr9qArNrSpsXeWIL2Go0', instrumentalness=0.954, key=5, liveness=0.0873, loudness=-33.218, mode=1, name='Sonata quasi Concerto, Op. 33, No. 3 in C: II. Adagio e cantabile, con espressione', popularity=0, release_date='1928', speechiness=0.043, tempo=74.04, valence=0.0917, year=1928),
#  Row(acousticness=0.991, artists="['Ignacio Corsini']", danceability=0.431, duration_ms=108573, energy=0.315, explicit=0, id='6mlX2fWNqtclyBUAyBHNQ5', instrumentalness=0.883, key=11, liveness=0.108, loudness=-21.753, mode=0, name='Caido del Cielo - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.0464, tempo=65.735, valence=0.711, year=1928),
#  Row(acousticness=0.991, artists="['Ted Weems & His Orchestra']", danceability=0.8390000000000001, duration_ms=162147, energy=0.37, explicit=0, id='6myKdOFzdAkk3npbTVrzFg', instrumentalness=0.0419, key=2, liveness=0.104, loudness=-11.602, mode=1, name='Chick, Chick, Chick, Chick, Chicken - Lay A Little Egg For Me', popularity=1, release_date='1928-07-01', speechiness=0.08, tempo=115.063, valence=0.976, year=1928),
#  Row(acousticness=0.991, artists="['Francisco Canaro', 'Charlo']", danceability=0.8290000000000001, duration_ms=175493, energy=0.199, explicit=0, id='6nRuUkty1Wsn3rPZgfpZ9F', instrumentalness=6.54e-06, key=10, liveness=0.119, loudness=-9.2, mode=0, name='Triste Paica - Remasterizado', popularity=0, release_date='1928-09-20', speechiness=0.0619, tempo=116.214, valence=0.6809999999999999, year=1928),
#  Row(acousticness=0.99, artists="['Ignacio Corsini']", danceability=0.7090000000000001, duration_ms=130813, energy=0.14800000000000002, explicit=0, id='6nxEIdbSzOtdi93IskacDT', instrumentalness=0.0262, key=3, liveness=0.131, loudness=-18.933, mode=0, name='Piedad - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.0775, tempo=122.415, valence=0.516, year=1928),
#  Row(acousticness=0.872, artists="['Taj Mahal']", danceability=0.5710000000000001, duration_ms=155893, energy=0.204, explicit=0, id='6oZyWbbisoG8jOunmpPH40', instrumentalness=0.779, key=6, liveness=0.197, loudness=-18.61, mode=1, name='Country Blues #1', popularity=0, release_date='1928', speechiness=0.0328, tempo=129.289, valence=0.0932, year=1928),
#  Row(acousticness=0.991, artists="['Francisco Canaro']", danceability=0.8079999999999999, duration_ms=194413, energy=0.215, explicit=0, id='6p5vkrnb0SdBxqHXNPn8Zs', instrumentalness=0.524, key=9, liveness=0.0906, loudness=-12.205, mode=1, name='La Cabeza del Italiano - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-17', speechiness=0.0851, tempo=110.894, valence=0.866, year=1928),
#  Row(acousticness=0.989, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.368, duration_ms=163800, energy=0.124, explicit=0, id='6p8Q6LG6m1kxAzTbUyIWN3', instrumentalness=0.892, key=0, liveness=0.105, loudness=-21.742, mode=0, name='Humoreske, Op. 20: Intermezzo', popularity=0, release_date='1928', speechiness=0.0371, tempo=128.418, valence=0.266, year=1928),
#  Row(acousticness=0.732, artists="['Seweryn Goszczyński']", danceability=0.72, duration_ms=100700, energy=0.28600000000000003, explicit=0, id='6qxoAGlWUrVYbvq3x6S08C', instrumentalness=0.0, key=5, liveness=0.292, loudness=-15.861, mode=1, name='Chapter 2.23 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.939, tempo=114.059, valence=0.695, year=1928),
#  Row(acousticness=0.991, artists="['Muzio Clementi', 'Vladimir Horowitz']", danceability=0.317, duration_ms=214667, energy=0.0916, explicit=0, id='6rIuHOee0surqjlxUWHruQ', instrumentalness=0.918, key=10, liveness=0.104, loudness=-30.682, mode=1, name='Rondo, No. 2', popularity=0, release_date='1928', speechiness=0.0411, tempo=80.74, valence=0.511, year=1928),
#  Row(acousticness=0.947, artists="['John Raitt']", danceability=0.333, duration_ms=122733, energy=0.146, explicit=0, id='6rd3MB90B6JcMzSsxTVX5P', instrumentalness=0.000426, key=2, liveness=0.265, loudness=-16.99, mode=1, name="Where's the Mate for Me?", popularity=2, release_date='1928', speechiness=0.0353, tempo=75.372, valence=0.234, year=1928),
#  Row(acousticness=0.986, artists="['Francisco Canaro']", danceability=0.613, duration_ms=303493, energy=0.187, explicit=0, id='6sHTmkp6k8genhaEHK5NxF', instrumentalness=0.804, key=1, liveness=0.111, loudness=-13.959, mode=1, name='Pájaro Azul - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-21', speechiness=0.255, tempo=116.325, valence=0.3, year=1928),
#  Row(acousticness=0.977, artists="['Ted Weems & His Orchestra']", danceability=0.757, duration_ms=180147, energy=0.49, explicit=0, id='6t2heLDAa5eqqLZM6yyDKw', instrumentalness=0.043, key=10, liveness=0.0885, loudness=-9.198, mode=1, name='It Was Only A Sun Shower', popularity=0, release_date='1928-07-01', speechiness=0.035, tempo=105.734, valence=0.836, year=1928),
#  Row(acousticness=0.974, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.188, duration_ms=236493, energy=0.0891, explicit=0, id='6tD8hbtg9YvauF84fl15sd', instrumentalness=0.8959999999999999, key=0, liveness=0.124, loudness=-25.936, mode=1, name='Andante spianato in E-Flat Major, Op. 22', popularity=3, release_date='1928', speechiness=0.0326, tempo=59.94600000000001, valence=0.16399999999999998, year=1928),
#  Row(acousticness=0.989, artists="['Francisco Canaro']", danceability=0.858, duration_ms=168413, energy=0.249, explicit=0, id='6tmVNRSYKtvrfhuuPnn7JK', instrumentalness=8.79e-05, key=2, liveness=0.181, loudness=-8.897, mode=1, name='Che Italiano - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-16', speechiness=0.224, tempo=115.858, valence=0.611, year=1928),
#  Row(acousticness=0.989, artists="['Paul Whiteman']", danceability=0.441, duration_ms=201053, energy=0.0454, explicit=0, id='6u4X5c1kV7hZrlMOD3FAco', instrumentalness=0.0752, key=7, liveness=0.0801, loudness=-21.884, mode=1, name='Chiquita', popularity=0, release_date='1928', speechiness=0.0463, tempo=133.475, valence=0.194, year=1928),
#  Row(acousticness=0.996, artists="['Ignacio Corsini']", danceability=0.675, duration_ms=145973, energy=0.127, explicit=0, id='6uORAJwv0yYp917APJP8Be', instrumentalness=0.0311, key=3, liveness=0.102, loudness=-21.612, mode=1, name='Destellos - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.226, tempo=129.58700000000002, valence=0.516, year=1928),
#  Row(acousticness=0.987, artists="['Samuel Barber', 'Vladimir Horowitz']", danceability=0.242, duration_ms=115627, energy=0.149, explicit=0, id='6v13FCz4z385EbNyPaXYCU', instrumentalness=0.877, key=0, liveness=0.134, loudness=-26.742, mode=1, name='Piano Sonata in E-Flat Minor, Op. 26: II. Allegro vivace e leggero', popularity=0, release_date='1928', speechiness=0.0369, tempo=88.18799999999996, valence=0.279, year=1928),
#  Row(acousticness=0.99, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.444, duration_ms=104013, energy=0.0431, explicit=0, id='6vK4MMy5CNIUNvFXlG9NuF', instrumentalness=0.889, key=1, liveness=0.124, loudness=-26.77, mode=1, name='Étude in G-Flat Major, Op. 10, No. 5 "Black Keys"', popularity=1, release_date='1928', speechiness=0.041, tempo=106.062, valence=0.404, year=1928),
#  Row(acousticness=0.725, artists="['Seweryn Goszczyński']", danceability=0.7909999999999999, duration_ms=107800, energy=0.234, explicit=0, id='6vniIHqoSV74xRTMdomqij', instrumentalness=0.0, key=8, liveness=0.152, loudness=-17.951, mode=1, name='Chapter 2.16 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.947, tempo=37.596, valence=0.705, year=1928),
#  Row(acousticness=0.99, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.272, duration_ms=473227, energy=0.281, explicit=0, id='6wt8PKNBSqNFqdOxgexvKu', instrumentalness=0.867, key=10, liveness=0.087, loudness=-16.227999999999998, mode=0, name='Piano Sonata No. 2, Op. 35: I. Grave - Doppio movimento', popularity=0, release_date='1928', speechiness=0.0365, tempo=99.27, valence=0.0775, year=1928),
#  Row(acousticness=0.993, artists="['Francisco Canaro', 'Charlo']", danceability=0.466, duration_ms=204000, energy=0.161, explicit=0, id='6x09M8ELRKDbwPH1y1uTje', instrumentalness=0.764, key=6, liveness=0.118, loudness=-13.007, mode=0, name='Always - Remasterizado', popularity=0, release_date='1928-09-25', speechiness=0.0576, tempo=75.24, valence=0.447, year=1928),
#  Row(acousticness=0.989, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.28, duration_ms=254107, energy=0.0463, explicit=0, id='6xpA90VSHtmaUhNltHIcVM', instrumentalness=0.873, key=11, liveness=0.0743, loudness=-19.78, mode=1, name='Nocturne in E Minor, Op. 72, No. 1', popularity=1, release_date='1928', speechiness=0.0347, tempo=100.131, valence=0.0722, year=1928),
#  Row(acousticness=0.995, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.389, duration_ms=94307, energy=0.263, explicit=0, id='6yOkXNFTUxZpnXXu1yJT3l', instrumentalness=0.914, key=5, liveness=0.128, loudness=-15.034, mode=0, name='Sonata No. 3, Op. 14: III: Variation II', popularity=0, release_date='1928', speechiness=0.0354, tempo=73.98100000000002, valence=0.188, year=1928),
#  Row(acousticness=0.993, artists="['Paul Whiteman']", danceability=0.523, duration_ms=202173, energy=0.0867, explicit=0, id='6yanEXQBzoNKlWJzKGBpsb', instrumentalness=0.124, key=10, liveness=0.14, loudness=-17.528, mode=1, name='Reaching for Someone (And Not Finding Anyone There)', popularity=1, release_date='1928', speechiness=0.0707, tempo=161.687, valence=0.6970000000000001, year=1928),
#  Row(acousticness=0.918, artists="['Leroy Carr']", danceability=0.754, duration_ms=184840, energy=0.194, explicit=0, id='6yx49288aRqkexZC1BoldM', instrumentalness=4.34e-05, key=3, liveness=0.188, loudness=-11.634, mode=1, name='Midnight Hour Blues', popularity=1, release_date='1928', speechiness=0.053, tempo=84.042, valence=0.454, year=1928),
#  Row(acousticness=0.992, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.301, duration_ms=785427, energy=0.0823, explicit=0, id='71FaVeFy9ZOiQRY4yOijey', instrumentalness=0.852, key=1, liveness=0.087, loudness=-23.282, mode=1, name='Polonaise-Fantaisie in A-Flat Major, Op. 61', popularity=0, release_date='1928', speechiness=0.0382, tempo=137.296, valence=0.0548, year=1928),
#  Row(acousticness=0.993, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.409, duration_ms=318267, energy=0.0224, explicit=0, id='722u6arjn98Ygql8TyqKZz', instrumentalness=0.908, key=1, liveness=0.13, loudness=-18.234, mode=1, name='Nocturne in C-Sharp Minor, Op. 27, No. 1 - 2001 Remastered', popularity=1, release_date='1928', speechiness=0.0441, tempo=126.458, valence=0.0655, year=1928),
#  Row(acousticness=0.995, artists="['Alexander Scriabin', 'Vladimir Horowitz']", danceability=0.411, duration_ms=97627, energy=0.211, explicit=0, id='72f1VDD6VELfZybK1Wkggy', instrumentalness=0.8759999999999999, key=2, liveness=0.106, loudness=-16.423, mode=0, name='Preludes: Op. 59, No. 2', popularity=0, release_date='1928', speechiness=0.0489, tempo=79.812, valence=0.119, year=1928),
#  Row(acousticness=0.992, artists="['Dmitry Kabalevsky', 'Vladimir Horowitz']", danceability=0.266, duration_ms=350373, energy=0.242, explicit=0, id='72iGv3PppJRsZwfT5ntZps', instrumentalness=0.915, key=10, liveness=0.154, loudness=-19.283, mode=0, name='Sonata No. 3, Op. 46: I. Allegro con moto', popularity=0, release_date='1928', speechiness=0.0314, tempo=86.43700000000004, valence=0.114, year=1928),
#  Row(acousticness=0.777, artists="['Seweryn Goszczyński']", danceability=0.748, duration_ms=110200, energy=0.295, explicit=0, id='72vD6lhG8KohMxjGqkKzBX', instrumentalness=0.0, key=9, liveness=0.122, loudness=-16.945, mode=1, name='Chapter 3.14 - Zamek kaniowski', popularity=0, release_date='1928', speechiness=0.94, tempo=114.431, valence=0.7170000000000001, year=1928),
#  Row(acousticness=0.994, artists="['Francisco Canaro']", danceability=0.79, duration_ms=160000, energy=0.171, explicit=0, id='73LY41HCJzlQwoNBmWM7Md', instrumentalness=0.0562, key=5, liveness=0.116, loudness=-13.993, mode=1, name='¿Te Acuerdas Mamita? - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-20', speechiness=0.221, tempo=121.646, valence=0.856, year=1928),
#  Row(acousticness=0.995, artists="['Ignacio Corsini']", danceability=0.579, duration_ms=136160, energy=0.33, explicit=0, id='747Dowy6MecKApVkFH1asI', instrumentalness=0.94, key=1, liveness=0.108, loudness=-20.558000000000003, mode=1, name='Quema Esas Cartas - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.055, tempo=134.545, valence=0.89, year=1928),
#  Row(acousticness=0.995, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.316, duration_ms=76960, energy=0.191, explicit=0, id='74qEIULd05bBGGtWiCglvC', instrumentalness=0.914, key=10, liveness=0.101, loudness=-16.249000000000002, mode=0, name='Sonata No. 3, Op. 14: III: Variation III', popularity=0, release_date='1928', speechiness=0.0389, tempo=109.331, valence=0.18, year=1928),
#  Row(acousticness=0.991, artists="['Frédéric Chopin', 'Vladimir Horowitz']", danceability=0.245, duration_ms=340973, energy=0.0577, explicit=0, id='74rczPEWk2w3Fl8eENpzuf', instrumentalness=0.882, key=5, liveness=0.0704, loudness=-24.98, mode=0, name='Nocturne F Minor, Op. 55, No. 1', popularity=0, release_date='1928', speechiness=0.0328, tempo=74.00399999999998, valence=0.105, year=1928),
#  Row(acousticness=0.992, artists="['Francisco Canaro', 'Charlo']", danceability=0.78, duration_ms=161000, energy=0.238, explicit=0, id='757cWe7lwe0BjpY1IRigot', instrumentalness=0.0355, key=3, liveness=0.108, loudness=-13.552, mode=0, name='Tu Disfraz - Remasterizado', popularity=0, release_date='1928-09-20', speechiness=0.209, tempo=121.064, valence=0.8440000000000001, year=1928),
#  Row(acousticness=0.995, artists="['Hikmet Rıza Hanım']", danceability=0.449, duration_ms=159496, energy=0.16899999999999998, explicit=0, id='75AyIcNnQzdiYln6BQJeps', instrumentalness=0.8320000000000001, key=7, liveness=0.0999, loudness=-12.993, mode=0, name='Ayva Çiçek Açmış', popularity=0, release_date='1928-05-11', speechiness=0.0497, tempo=66.372, valence=0.413, year=1928),
#  Row(acousticness=0.993, artists="['Francisco Canaro']", danceability=0.7659999999999999, duration_ms=184000, energy=0.203, explicit=0, id='75PDI4YUCg84Y0Nt0KAKa1', instrumentalness=0.16899999999999998, key=2, liveness=0.147, loudness=-10.142, mode=0, name='Emoción - Instrumental (Remasterizado)', popularity=0, release_date='1928-09-25', speechiness=0.0728, tempo=116.415, valence=0.6920000000000001, year=1928),
#  Row(acousticness=0.995, artists="['Ignacio Corsini']", danceability=0.599, duration_ms=135507, energy=0.13699999999999998, explicit=0, id='75Tt3zPHlYnejhusIUy50f', instrumentalness=0.305, key=5, liveness=0.132, loudness=-22.342, mode=0, name='Cualquier Cosa - Remasterizado', popularity=0, release_date='1928-05-14', speechiness=0.161, tempo=137.384, valence=0.687, year=1928),
#  Row(acousticness=0.994, artists="['Francisco Canaro', 'Charlo']", danceability=0.615, duration_ms=170000, energy=0.205, explicit=0, id='75vvVnUqj8PlyJBAZ494p3', instrumentalness=0.913, key=2, liveness=0.113, loudness=-13.837, mode=1, name='Pobre Gaucho - Remasterizado', popularity=0, release_date='1928-10-03', speechiness=0.0618, tempo=58.299, valence=0.752, year=1928),
#  Row(acousticness=0.996, artists="['Alexander Scriabin', 'Vladimir Horowitz']", danceability=0.278, duration_ms=288907, energy=0.0049, explicit=0, id='75yPZGkLb31Q4dRFqzMF5z', instrumentalness=0.932, key=11, liveness=0.0954, loudness=-31.442, mode=1, name='Sonata No. 3, Op. 23 in F-Sharp Minor: III. Andante', popularity=0, release_date='1928', speechiness=0.0407, tempo=81.033, valence=0.0606, year=1928),
#  Row(acousticness=0.996, artists="['Alexander Scriabin', 'Vladimir Horowitz']", danceability=0.393, duration_ms=48627, energy=0.0545, explicit=0, id='75zIt9muIwtL6o30PcqskO', instrumentalness=0.8290000000000001, key=7, liveness=0.328, loudness=-27.582, mode=1, name='Preludes: Op. 11, No. 3 in G', popularity=0, release_date='1928', speechiness=0.0366, tempo=70.495, valence=0.374, year=1928),
#  Row(acousticness=0.105, artists="['Shungi Music Crew']", danceability=0.6990000000000001, duration_ms=388115, energy=0.838, explicit=0, id='764wHEOb2yPgsJHmU0J4ZS', instrumentalness=0.909, key=7, liveness=0.128, loudness=-12.106, mode=1, name='Trip to Limpopo', popularity=0, release_date='1928-08-20', speechiness=0.0462, tempo=123.993, valence=0.481, year=1928),
#  Row(acousticness=0.981, artists="['Elsie Houston']", danceability=0.78, duration_ms=117362, energy=0.55, explicit=0, id='3yH0dcIQudG7VcC0kB4T8V', instrumentalness=0.122, key=4, liveness=0.165, loudness=-11.095999999999998, mode=0, name='Óia o Sapo', popularity=0, release_date='1930-12-31', speechiness=0.396, tempo=83.383, valence=0.847, year=1930),
#  Row(acousticness=0.991, artists="['Ignacio Corsini']", danceability=0.545, duration_ms=168653, energy=0.133, explicit=0, id='3yZj8i9TwsWAVmBWKdMbaa', instrumentalness=0.444, key=7, liveness=0.115, loudness=-20.53, mode=0, name='Cobardia - Remasterizado', popularity=0, release_date='1930-06-21', speechiness=0.127, tempo=185.062, valence=0.691, year=1930),
#  Row(acousticness=0.995, artists="['Francisco Canaro']", danceability=0.746, duration_ms=186000, energy=0.159, explicit=0, id='3yqMsVEs3Fq3jzsibskXeY', instrumentalness=0.8190000000000001, key=8, liveness=0.109, loudness=-15.106, mode=1, name='Asuero - Instrumental (Remasterizado)', popularity=0, release_date='1930-11-20', speechiness=0.189, tempo=120.084, valence=0.88, year=1930),
#  Row(acousticness=0.981, artists="['Αντώνης Νταλγκάς']", danceability=0.273, duration_ms=200693, energy=0.0958, explicit=0, id='3ysZe4AZtpys3VbZabN0Nh', instrumentalness=0.00109, key=1, liveness=0.637, loudness=-20.217, mode=1, name='Μπεστενγκιάρ μανές', popularity=0, release_date='1930-01-01', speechiness=0.0465, tempo=86.281, valence=0.18, year=1930),
#  Row(acousticness=0.982, artists="['Stellakis Perpiniadis']", danceability=0.503, duration_ms=188120, energy=0.46, explicit=0, id='3zFy6I5USXgmG18E3f1971', instrumentalness=0.78, key=9, liveness=0.157, loudness=-9.289, mode=0, name='O milonas', popularity=0, release_date='1930-01-01', speechiness=0.0454, tempo=79.26899999999998, valence=0.909, year=1930),
#  Row(acousticness=0.989, artists="['Αντώνης Διαμαντίδης']", danceability=0.414, duration_ms=165520, energy=0.229, explicit=0, id='3zGslzrt12d41TKH7xBO5R', instrumentalness=0.00067, key=7, liveness=0.121, loudness=-10.564, mode=1, name='Θεοδωράκης Γρίβας', popularity=0, release_date='1930-01-01', speechiness=0.0587, tempo=74.796, valence=0.325, year=1930),
#  Row(acousticness=0.992, artists="['S. Loukopoulos', 'Klarino G. Anestopoulos', 'Klarino KOstas Giaouzos', 'Klarinos Nikos Karakostas']", danceability=0.368, duration_ms=204840, energy=0.263, explicit=0, id='3zK60VaQyLm9Tbrji7v4eX', instrumentalness=0.89, key=9, liveness=0.28800000000000003, loudness=-16.262999999999998, mode=1, name='Xipna Pouli Mou To Proi', popularity=0, release_date='1930-01-01', speechiness=0.0476, tempo=101.447, valence=0.312, year=1930),
#  Row(acousticness=0.996, artists="['Paradosiako I. KIriakatis']", danceability=0.342, duration_ms=178154, energy=0.308, explicit=0, id='3zYsOagWsmCQ0OwREYFxJ2', instrumentalness=0.903, key=0, liveness=0.14, loudness=-13.483, mode=1, name='Kenouria Logia', popularity=0, release_date='1930-01-01', speechiness=0.0564, tempo=74.733, valence=0.949, year=1930),
#  Row(acousticness=0.951, artists="['Moune De Rivel']", danceability=0.69, duration_ms=169509, energy=0.7140000000000001, explicit=0, id='3zhptXjoaB6EF8WUtde9iA', instrumentalness=0.000348, key=0, liveness=0.234, loudness=-15.857, mode=0, name='Kiembeli', popularity=2, release_date='1930-01-01', speechiness=0.0747, tempo=116.188, valence=0.804, year=1930),
#  Row(acousticness=0.994, artists="['Dimitris Gkogkos']", danceability=0.552, duration_ms=194880, energy=0.275, explicit=0, id='402nzcLa8CkqfeD3GzEy6j', instrumentalness=0.8290000000000001, key=11, liveness=0.11, loudness=-12.746, mode=0, name='Matia glika kai galana', popularity=0, release_date='1930-01-01', speechiness=0.0599, tempo=117.057, valence=0.544, year=1930),
#  Row(acousticness=0.962, artists="['Giorgos Papasideris']", danceability=0.32, duration_ms=185307, energy=0.529, explicit=0, id='404Vsdauw3WGz3FG8Qwv9A', instrumentalness=0.392, key=9, liveness=0.117, loudness=-7.449, mode=1, name='Kalikie', popularity=0, release_date='1930-01-01', speechiness=0.0474, tempo=79.649, valence=0.858, year=1930),
#  Row(acousticness=0.994, artists="['Petros Epitropakis', 'Antonis Kalampousis']", danceability=0.14400000000000002, duration_ms=211399, energy=0.331, explicit=0, id='40AkLtfyKR89OxRaf3X9zh', instrumentalness=0.88, key=4, liveness=0.145, loudness=-13.406, mode=0, name='San Oneiro', popularity=0, release_date='1930-01-01', speechiness=0.0428, tempo=71.956, valence=0.16399999999999998, year=1930),
#  Row(acousticness=0.29, artists="['Cellular Project']", danceability=0.344, duration_ms=192332, energy=0.857, explicit=0, id='40P3zk2IX1Iannfbz89mO2', instrumentalness=0.8740000000000001, key=3, liveness=0.125, loudness=-5.441, mode=1, name='Purple Daze', popularity=0, release_date='1930', speechiness=0.0507, tempo=140.66899999999998, valence=0.158, year=1930),
#  Row(acousticness=0.971, artists="['Francisco Canaro', 'Luis Diaz']", danceability=0.807, duration_ms=207493, energy=0.202, explicit=0, id='40c7MoKLp6KVavEdHLBINz', instrumentalness=0.161, key=6, liveness=0.0561, loudness=-13.675, mode=1, name='Cascabeles - Remasterizado', popularity=0, release_date='1930-12-03', speechiness=0.184, tempo=115.364, valence=0.8859999999999999, year=1930),
#  Row(acousticness=0.989, artists="['Francisco Canaro', 'Charlo']", danceability=0.445, duration_ms=185507, energy=0.28800000000000003, explicit=0, id='40jiorcB4ujhNCJEM3NYRz', instrumentalness=0.758, key=2, liveness=0.111, loudness=-8.925, mode=1, name='Cantando Bajo la Lluvia - Remasterizado', popularity=0, release_date='1930-11-12', speechiness=0.0699, tempo=205.423, valence=0.6970000000000001, year=1930),
#  Row(acousticness=0.996, artists="['Sotiris Stasinopoulos']", danceability=0.269, duration_ms=271560, energy=0.319, explicit=0, id='40lNmAqzsDxT1aV39oakv4', instrumentalness=0.882, key=7, liveness=0.196, loudness=-16.218, mode=1, name='Kovo Mia Klara', popularity=0, release_date='1930-01-01', speechiness=0.0514, tempo=75.833, valence=0.447, year=1930),
#  Row(acousticness=0.971, artists="['Nota Kaleli']", danceability=0.74, duration_ms=30000, energy=0.508, explicit=0, id='40q1O23P19AcDSghky2Ct3', instrumentalness=0.946, key=2, liveness=0.134, loudness=-11.353, mode=1, name='Pagkratiotissa mou', popularity=0, release_date='1930-01-01', speechiness=0.063, tempo=76.43, valence=0.967, year=1930),
#  Row(acousticness=0.87, artists="['Robert Francis']", danceability=0.353, duration_ms=137090, energy=0.0785, explicit=0, id='41FFRKj6ehfOer45QC85mm', instrumentalness=2.21e-06, key=0, liveness=0.112, loudness=-18.434, mode=0, name='My Funny Valentine', popularity=2, release_date='1930', speechiness=0.0376, tempo=70.535, valence=0.261, year=1930),
#  Row(acousticness=0.99, artists="['Francisco Canaro', 'Roberto Maida']", danceability=0.518, duration_ms=174493, energy=0.462, explicit=0, id='41fXcqGebIUYOFQvDzqLJG', instrumentalness=0.85, key=4, liveness=0.157, loudness=-9.632, mode=0, name='A Lo Lejos - Remasterizado', popularity=0, release_date='1930-12-03', speechiness=0.377, tempo=178.88, valence=0.696, year=1930),
#  Row(acousticness=0.991, artists="['The Caresser']", danceability=0.574, duration_ms=189571, energy=0.3720000000000001, explicit=0, id='41ot3rSkTwJ7tLBut2jmH5', instrumentalness=0.000129, key=4, liveness=0.877, loudness=-9.888, mode=0, name='Edward the VIII', popularity=1, release_date='1930-01-01', speechiness=0.0592, tempo=88.836, valence=0.8740000000000001, year=1930),
#  Row(acousticness=0.991, artists="['Soula Karagiorgi']", danceability=0.358, duration_ms=182733, energy=0.35, explicit=0, id='41uoJrpHQhmOAkcXtKsAk3', instrumentalness=0.0387, key=2, liveness=0.348, loudness=-13.585, mode=1, name='Skliri Kardia', popularity=0, release_date='1930-01-01', speechiness=0.0392, tempo=113.337, valence=0.305, year=1930),
#  Row(acousticness=0.779, artists="['The Merlons']", danceability=0.4270000000000001, duration_ms=128707, energy=0.531, explicit=0, id='41wmjlc9ChMBHZ8fB0btdM', instrumentalness=0.978, key=0, liveness=0.145, loudness=-16.675, mode=1, name='Loda', popularity=0, release_date='1930', speechiness=0.0325, tempo=110.993, valence=0.353, year=1930),
#  Row(acousticness=0.994, artists="['Francisco Canaro', 'Charlo', 'Angel Ramos']", danceability=0.6, duration_ms=202000, energy=0.174, explicit=0, id='4285vY2v7Z1Kyh3Gi3sDrz', instrumentalness=0.805, key=4, liveness=0.173, loudness=-9.047, mode=1, name='Clavel del Aire - Remasterizado', popularity=0, release_date='1930-11-13', speechiness=0.0449, tempo=118.107, valence=0.594, year=1930),
#  Row(acousticness=0.977, artists="['Κώστας Δούσιας']", danceability=0.611, duration_ms=240160, energy=0.38, explicit=0, id='428NvDHsWDUzEBUjvmfCFW', instrumentalness=0.000192, key=10, liveness=0.117, loudness=-16.791, mode=1, name='Το καλογεράκι', popularity=0, release_date='1930-01-01', speechiness=0.0586, tempo=147.909, valence=0.654, year=1930),
#  Row(acousticness=0.996, artists="['Miltiadis Kazis']", danceability=0.401, duration_ms=253121, energy=0.354, explicit=0, id='42Ij0aAdwHtw9bOykDyGie', instrumentalness=0.0123, key=2, liveness=0.248, loudness=-8.238, mode=1, name='Kanella kanellitsa mou', popularity=0, release_date='1930-01-01', speechiness=0.0387, tempo=113.026, valence=0.797, year=1930),
# ...
#  Row(acousticness=0.846, artists="['Shamshad Begum']", danceability=0.564, duration_ms=211867, energy=0.29, explicit=0, id='1gvON2x95M5nNuk9aSHcaF', instrumentalness=5.37e-05, key=5, liveness=0.358, loudness=-10.134, mode=1, name='Do Char Din Pyar Se', popularity=0, release_date='1949-12-31', speechiness=0.47, tempo=85.546, valence=0.569, year=1949),
#  Row(acousticness=0.992, artists="['Giacomo Rondinella']", danceability=0.261, duration_ms=167053, energy=0.276, explicit=0, id='1hB2sfui5H9La7w98ZCxb8', instrumentalness=0.00965, key=7, liveness=0.315, loudness=-16.570999999999998, mode=1, name='Sulo', popularity=0, release_date='1949-01-01', speechiness=0.0572, tempo=80.67699999999998, valence=0.0909, year=1949),
#  Row(acousticness=0.981, artists="['Irving Berlin', 'Johnny V. R. Thompson', 'Allyn McLerie', 'Miss Liberty Ensemble', 'Jay Blackton']", danceability=0.243, duration_ms=173093, energy=0.175, explicit=0, id='1hf7hC5MYb86001qzR5rBJ', instrumentalness=0.000128, key=0, liveness=0.14, loudness=-14.149, mode=1, name='Miss Liberty: Paris Wakes Up and Smiles', popularity=0, release_date='1949', speechiness=0.0409, tempo=80.666, valence=0.226, year=1949),
#  Row(acousticness=0.787, artists="['Giuseppe Verdi', 'Arturo Toscanini']", danceability=0.411, duration_ms=53013, energy=0.408, explicit=0, id='1hrASLD1BLLXJkDGGgOtTA', instrumentalness=0.469, key=2, liveness=0.3, loudness=-11.397, mode=0, name='Aida: Traditor!', popularity=0, release_date='1949', speechiness=0.0855, tempo=136.957, valence=0.403, year=1949),
#  Row(acousticness=0.8270000000000001, artists="['Shanta Kunwar']", danceability=0.528, duration_ms=212287, energy=0.471, explicit=0, id='1hu5Dh8Ke8h7ZzCRcqWaFx', instrumentalness=0.00355, key=9, liveness=0.391, loudness=-9.84, mode=1, name='Armaan Loot Gaye Hae', popularity=0, release_date='1949-12-31', speechiness=0.0424, tempo=131.875, valence=0.71, year=1949),
#  Row(acousticness=0.802, artists="['Lead Belly']", danceability=0.409, duration_ms=193123, energy=0.672, explicit=0, id='1i8C8u3CVtM4NmaPGNXBNk', instrumentalness=0.494, key=9, liveness=0.313, loudness=-8.601, mode=1, name='John Henry', popularity=0, release_date='1949', speechiness=0.0409, tempo=145.218, valence=0.731, year=1949),
#  Row(acousticness=0.91, artists="['Jay Blackton', 'Laurence Guittard', 'Christine Andreas']", danceability=0.27, duration_ms=257107, energy=0.16, explicit=0, id='1iYOEFvQbSmRrzIldiIWvP', instrumentalness=0.000388, key=9, liveness=0.0963, loudness=-17.246, mode=1, name='People Will Say We\'re in Love (From "Oklahoma!")', popularity=1, release_date='1949', speechiness=0.0342, tempo=78.0, valence=0.203, year=1949),
#  Row(acousticness=0.965, artists="['Fromental Halévy', 'Richard Tucker', 'Wilfrid Pelletier']", danceability=0.237, duration_ms=259867, energy=0.18, explicit=0, id='1ivbgk5DS1fAppzMVqeVF1', instrumentalness=5.1e-06, key=5, liveness=0.0963, loudness=-14.207, mode=0, name='La Juive: "Rachel, quand du seigneur"', popularity=0, release_date='1949', speechiness=0.0397, tempo=92.726, valence=0.149, year=1949),
#  Row(acousticness=0.995, artists="['Robin Majumdar']", danceability=0.589, duration_ms=183347, energy=0.185, explicit=0, id='1jF9tFdbK6wAxRN4NTYan2', instrumentalness=0.93, key=11, liveness=0.106, loudness=-17.535, mode=1, name='Moni Maniker Pasara', popularity=0, release_date='1949-12-31', speechiness=0.0753, tempo=130.33, valence=0.551, year=1949),
#  Row(acousticness=0.993, artists="['Dilip Dholakia']", danceability=0.459, duration_ms=194252, energy=0.282, explicit=0, id='1jMQqsOw6QHC4Mq5WXVBSb', instrumentalness=0.306, key=7, liveness=0.337, loudness=-8.994, mode=1, name='Bhala Bhalae Bhool Kari', popularity=0, release_date='1949-03-02', speechiness=0.14800000000000002, tempo=64.84899999999999, valence=0.417, year=1949),
#  Row(acousticness=0.778, artists="['Bourvil']", danceability=0.637, duration_ms=194533, energy=0.345, explicit=0, id='1jjZsdtrgJDPEDIOfLJtyo', instrumentalness=0.0, key=3, liveness=0.0793, loudness=-10.125, mode=1, name='Ma place', popularity=1, release_date='1949', speechiness=0.153, tempo=80.075, valence=0.648, year=1949),
#  Row(acousticness=0.995, artists="['Sulochana Kadam']", danceability=0.754, duration_ms=173964, energy=0.35100000000000003, explicit=0, id='1jl449khYMkGlVb3RhPYi0', instrumentalness=0.7559999999999999, key=0, liveness=0.126, loudness=-9.378, mode=0, name='Jahan Koi Na Ho Wahan Chalenge Ham', popularity=0, release_date='1949-12-31', speechiness=0.111, tempo=148.899, valence=0.96, year=1949),
#  Row(acousticness=0.993, artists="['Wolfgang Amadeus Mozart', 'Bruno Walter', 'Columbia Symphony Orchestra']", danceability=0.502, duration_ms=147333, energy=0.252, explicit=0, id='1jsOMnrDvxZDHZqvoIu5C9', instrumentalness=0.0138, key=7, liveness=0.155, loudness=-12.196, mode=1, name='Die Entführung aus dem Serail, K. 384, Act II: "Welche Wonne.."', popularity=0, release_date='1949', speechiness=0.114, tempo=75.835, valence=0.565, year=1949),
#  Row(acousticness=0.858, artists="['Lalita Dewoolkar']", danceability=0.513, duration_ms=241653, energy=0.364, explicit=0, id='1juCEmPAkt2OiC8UqB7I0A', instrumentalness=0.000199, key=9, liveness=0.155, loudness=-11.102, mode=1, name='Dil Leke Bhaga', popularity=0, release_date='1949-12-31', speechiness=0.0924, tempo=180.836, valence=0.755, year=1949),
#  Row(acousticness=0.974, artists="['Ernest Bloch', 'Isaac Stern', 'Alexander Zakin']", danceability=0.253, duration_ms=379267, energy=0.206, explicit=0, id='1k80cWFHXq0lfIJg9Exj9y', instrumentalness=0.7290000000000001, key=7, liveness=0.159, loudness=-16.584, mode=0, name='Baal Shem - Three PIctures of Chassidic Life: II. Nigun', popularity=0, release_date='1949', speechiness=0.0421, tempo=104.804, valence=0.0924, year=1949),
#  Row(acousticness=0.959, artists="['Mitch Miller & The Sing-Along Gang']", danceability=0.109, duration_ms=260867, energy=0.273, explicit=0, id='1k8Z5FY3QFBJtm4a63aF5p', instrumentalness=0.000466, key=10, liveness=0.124, loudness=-14.77, mode=1, name='Silent Night, Holy Night', popularity=1, release_date='1949', speechiness=0.0356, tempo=71.313, valence=0.103, year=1949),
#  Row(acousticness=0.991, artists="['Κούλα Νικολαϊδου']", danceability=0.41, duration_ms=95935, energy=0.311, explicit=0, id='1kG5glfzBWVa0W3cL2sbGv', instrumentalness=4.77e-05, key=10, liveness=0.21600000000000005, loudness=-9.951, mode=1, name='Απόψε πάλι', popularity=0, release_date='1949-01-01', speechiness=0.0394, tempo=96.012, valence=0.505, year=1949),
#  Row(acousticness=0.966, artists="['Johannes Brahms', 'Wilhelm Furtwängler', 'Wiener Philharmoniker']", danceability=0.127, duration_ms=197813, energy=0.218, explicit=0, id='1kqWugFghxSx3rjDtf2XQl', instrumentalness=0.921, key=10, liveness=0.335, loudness=-15.989, mode=1, name='Brahms: Variations on a Theme by Haydn, Op. 56a "St. Antoni Chorale": Variation VII. Grazioso', popularity=0, release_date='1949', speechiness=0.036000000000000004, tempo=147.935, valence=0.116, year=1949),
#  Row(acousticness=0.946, artists="['Nikolai Rimsky-Korsakov', 'Mario Lanza', 'Constantine Callinicos']", danceability=0.238, duration_ms=239253, energy=0.301, explicit=0, id='1ktOaQeEQRMv9B5XOoa88t', instrumentalness=0.000918, key=1, liveness=0.109, loudness=-9.804, mode=1, name='Sadko: Song of India', popularity=1, release_date='1949', speechiness=0.0314, tempo=93.734, valence=0.269, year=1949),
#  Row(acousticness=0.959, artists="['Ralph Vaughan Williams', 'Leopold Stokowski', 'New York Philharmonic']", danceability=0.113, duration_ms=517733, energy=0.0173, explicit=0, id='1kwpuqFRYEeM01Ccg5P9kb', instrumentalness=0.888, key=0, liveness=0.116, loudness=-34.677, mode=1, name='Symphony No. 6 in E Minor: IV. Epilogue', popularity=0, release_date='1949', speechiness=0.0444, tempo=93.826, valence=0.0346, year=1949),
#  Row(acousticness=0.984, artists="['Aaron Copland', 'Martha Lipton']", danceability=0.3720000000000001, duration_ms=136133, energy=0.152, explicit=0, id='1lN3jH5YqsNzHDRqjqKlZD', instrumentalness=0.000174, key=1, liveness=0.0982, loudness=-13.61, mode=1, name='Twelve Poems of Emily Dickinson: IX. I felt a funeral in my brain', popularity=0, release_date='1949', speechiness=0.063, tempo=173.447, valence=0.051, year=1949),
#  Row(acousticness=0.669, artists="['Anton Bruckner', 'Wiener Philharmoniker', 'Hans Knappertsbusch']", danceability=0.16699999999999998, duration_ms=1220467, energy=0.123, explicit=0, id='1lSlNDHyjHq67U92wbwczi', instrumentalness=0.217, key=11, liveness=0.289, loudness=-20.217, mode=1, name='Symphony No. 7 in E Major, WAB 107 (Modified 1885 Version, Ed. A. Gutmann): I. Allegro moderato [Live]', popularity=0, release_date='1949-08-30', speechiness=0.04, tempo=104.871, valence=0.039, year=1949),
#  Row(acousticness=0.8759999999999999, artists="['George Gershwin', 'Mary Martin', 'Girl Crazy Ensemble (1952)', 'Lehman Engel']", danceability=0.426, duration_ms=173533, energy=0.302, explicit=0, id='1lT06EeLeQEzOYD9X8tCby', instrumentalness=0.0, key=7, liveness=0.522, loudness=-11.286, mode=1, name='Girl Crazy: Boy! What Love Has Done to Me', popularity=1, release_date='1949', speechiness=0.0437, tempo=85.654, valence=0.408, year=1949),
#  Row(acousticness=0.536, artists="['Munawwar Sultana']", danceability=0.61, duration_ms=167027, energy=0.455, explicit=0, id='1lTGhbAlGF8wvzUbWmutby', instrumentalness=8.53e-05, key=5, liveness=0.419, loudness=-9.605, mode=0, name='Dil ko rahat nahin qarar nahin', popularity=0, release_date='1949-01-01', speechiness=0.0701, tempo=76.89, valence=0.472, year=1949),
#  Row(acousticness=0.838, artists="['Lead Belly']", danceability=0.599, duration_ms=65698, energy=0.321, explicit=0, id='1lgnLRxxnFqaXxMlZNyWKj', instrumentalness=0.0, key=2, liveness=0.156, loudness=-9.407, mode=0, name='Come And Sit Down Beside Me', popularity=0, release_date='1949', speechiness=0.0354, tempo=87.006, valence=0.919, year=1949),
#  Row(acousticness=0.8490000000000001, artists="['Hariram']", danceability=0.618, duration_ms=203314, energy=0.202, explicit=0, id='1ljivYBdnsquYYJMmRXupX', instrumentalness=1.05e-06, key=0, liveness=0.413, loudness=-18.214, mode=1, name='Gagar Gai Bharne Sakhi', popularity=0, release_date='1949-12-31', speechiness=0.0461, tempo=81.032, valence=0.935, year=1949),
#  Row(acousticness=0.988, artists="['Giacomo Puccini', 'Richard Tucker', 'Dorothy Kirsten', 'Fausto Cleva']", danceability=0.179, duration_ms=221013, energy=0.212, explicit=0, id='1lkfS36M4GobrT3QVhrA6S', instrumentalness=0.0095, key=4, liveness=0.124, loudness=-12.348, mode=1, name='La bohème, Act I:"O soave fanciulla"', popularity=0, release_date='1949', speechiness=0.0402, tempo=83.141, valence=0.0507, year=1949),
#  Row(acousticness=0.979, artists="['Charles Mingus']", danceability=0.248, duration_ms=245133, energy=0.219, explicit=0, id='1lzMkGUlTgyMUbrp1j9A3N', instrumentalness=0.905, key=5, liveness=0.123, loudness=-13.591, mode=0, name='Inspiration', popularity=3, release_date='1949', speechiness=0.0292, tempo=76.779, valence=0.0946, year=1949),
#  Row(acousticness=0.948, artists="['Joaquín Rodrigo', 'Andrés Segovia']", danceability=0.479, duration_ms=225019, energy=0.13699999999999998, explicit=0, id='1m02sEzI88HcByzEM8goMH', instrumentalness=0.74, key=4, liveness=0.236, loudness=-24.695, mode=1, name='Fandango', popularity=0, release_date='1949-01-01', speechiness=0.0383, tempo=90.29, valence=0.485, year=1949),
#  Row(acousticness=0.937, artists="['Giuseppe Verdi', 'Arturo Toscanini']", danceability=0.274, duration_ms=100573, energy=0.123, explicit=0, id='1m7WbravGKJ9iilTKOywFz', instrumentalness=7.06e-05, key=1, liveness=0.246, loudness=-19.687, mode=1, name="Aida: Vedi? Di morte l'angelo", popularity=0, release_date='1949', speechiness=0.0456, tempo=72.428, valence=0.238, year=1949),
#  Row(acousticness=0.978, artists="['Giuseppe Verdi', 'Arturo Toscanini']", danceability=0.15, duration_ms=266787, energy=0.116, explicit=0, id='1m8Hj7ER6ixH30KApRpVZj', instrumentalness=0.00372, key=3, liveness=0.108, loudness=-19.381, mode=1, name='Aida: Nume, custode e vindice', popularity=0, release_date='1949', speechiness=0.036000000000000004, tempo=60.015, valence=0.16899999999999998, year=1949),
#  Row(acousticness=0.987, artists="['Giacomo Puccini', 'Richard Tucker', 'Fausto Cleva [Conductor]']", danceability=0.274, duration_ms=275840, energy=0.251, explicit=0, id='1m8epcwSD06TJu7kYyTv1m', instrumentalness=9.48e-06, key=7, liveness=0.246, loudness=-12.113, mode=1, name='La Bohême, Act I: "Che gelida manina"', popularity=0, release_date='1949', speechiness=0.0401, tempo=126.229, valence=0.11, year=1949),
#  Row(acousticness=0.941, artists="['Giuseppe Verdi', 'Arturo Toscanini']", danceability=0.203, duration_ms=98507, energy=0.103, explicit=0, id='1m9BazgCOGMJxmyqE30grw', instrumentalness=0.0218, key=2, liveness=0.364, loudness=-23.632, mode=0, name='Aida: Qui Radamès verrà!', popularity=0, release_date='1949', speechiness=0.0425, tempo=81.033, valence=0.103, year=1949),
#  Row(acousticness=0.952, artists="['Ezio Pinza']", danceability=0.243, duration_ms=180693, energy=0.234, explicit=0, id='1mANcjsYwOOSQJdf8dIL1Y', instrumentalness=0.00182, key=0, liveness=0.0964, loudness=-13.954, mode=1, name='Some Enchanted Evening - from "South Pacific, 1949"', popularity=0, release_date='1949', speechiness=0.0394, tempo=90.851, valence=0.222, year=1949),
#  Row(acousticness=0.7979999999999999, artists="['Franz von Suppé', 'London Philharmonic Orchestra', 'Sir Georg Solti']", danceability=0.241, duration_ms=494053, energy=0.268, explicit=0, id='1mVlcXbhcRM0Ie9nydrC6d', instrumentalness=0.000536, key=2, liveness=0.0708, loudness=-11.583, mode=1, name='Poet and Peasant: Overture', popularity=0, release_date='1949', speechiness=0.0512, tempo=87.945, valence=0.244, year=1949),
#  Row(acousticness=0.996, artists="['Suraiya', 'Mukesh']", danceability=0.362, duration_ms=190880, energy=0.232, explicit=0, id='1mdGSkdBhCvCBTDDcRkCgy', instrumentalness=0.883, key=3, liveness=0.129, loudness=-14.586, mode=1, name='Badra Ki Chhaon Tale', popularity=0, release_date='1949-01-01', speechiness=0.14, tempo=66.59899999999999, valence=0.498, year=1949),
#  Row(acousticness=0.953, artists="['N. S. Krishnan', 'T A Madhuram']", danceability=0.602, duration_ms=197240, energy=0.408, explicit=0, id='1nItTy4DPU7LcrbGAfLkcp', instrumentalness=0.0208, key=1, liveness=0.124, loudness=-8.579, mode=1, name='Vignanathai', popularity=0, release_date='1949-12-01', speechiness=0.48, tempo=67.748, valence=0.816, year=1949),
#  Row(acousticness=0.994, artists="['Lalita Phadke', 'Balakram']", danceability=0.805, duration_ms=167787, energy=0.269, explicit=0, id='1nMOUk1hLge8FdFEdZ98TB', instrumentalness=0.546, key=8, liveness=0.122, loudness=-9.15, mode=0, name='Bachpan Mera Bachpan Tera', popularity=0, release_date='1949-12-31', speechiness=0.487, tempo=101.197, valence=0.835, year=1949),
#  Row(acousticness=0.945, artists="['Lead Belly']", danceability=0.7020000000000001, duration_ms=202707, energy=0.32, explicit=0, id='1nPu67v2i3iWqdiZYY48Uf', instrumentalness=0.00118, key=5, liveness=0.68, loudness=-9.817, mode=1, name='Whoa Buck', popularity=0, release_date='1949', speechiness=0.353, tempo=75.967, valence=0.465, year=1949),
#  Row(acousticness=0.529, artists="['Frank Wedekind']", danceability=0.6629999999999999, duration_ms=140400, energy=0.153, explicit=0, id='1ncMthnYcUTBCSPEoelULc', instrumentalness=0.0, key=5, liveness=0.194, loudness=-29.06, mode=1, name='Kapitel 20 - Der Kammersänger', popularity=0, release_date='1949-03-12', speechiness=0.925, tempo=145.585, valence=0.27, year=1949),
#  Row(acousticness=0.73, artists="['Maurice Ravel', 'Pierre Monteux']", danceability=0.295, duration_ms=425453, energy=0.21, explicit=0, id='1nq1Rwjoq6dmKuKay15MUN', instrumentalness=0.57, key=2, liveness=0.0995, loudness=-16.410999999999998, mode=1, name='Alborada del gracioso', popularity=0, release_date='1949', speechiness=0.0501, tempo=127.926, valence=0.122, year=1949),
#  ...]

# %%
#"take(num)" returns the first num of rows as a list.
spotify.take(2)
# Out:
# [Row(acousticness=0.995, artists="['Carl Woitschach']", danceability=0.708, duration_ms=158648, energy=0.195, explicit=0, id='6KbQ3uYMLKb5jDxLF7wYDD', instrumentalness=0.563, key=10, liveness=0.151, loudness=-12.428, mode=1, name='Singende Bataillone 1. Teil', popularity=0, release_date='1928', speechiness=0.0506, tempo=118.469, valence=0.779, year=1928),
#  Row(acousticness=0.994, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.379, duration_ms=282133, energy=0.0135, explicit=0, id='6KuQTIu1KoTTkLXKrwlLPV', instrumentalness=0.901, key=8, liveness=0.0763, loudness=-28.454, mode=1, name='Fantasiestücke, Op. 111: Più tosto lento', popularity=0, release_date='1928', speechiness=0.0462, tempo=83.97200000000002, valence=0.0767, year=1928)]

# %%
#".head(num)" Returns first num of rows as a list. (SAME!)
spotify.head(2)
# Out:
# [Row(acousticness=0.995, artists="['Carl Woitschach']", danceability=0.708, duration_ms=158648, energy=0.195, explicit=0, id='6KbQ3uYMLKb5jDxLF7wYDD', instrumentalness=0.563, key=10, liveness=0.151, loudness=-12.428, mode=1, name='Singende Bataillone 1. Teil', popularity=0, release_date='1928', speechiness=0.0506, tempo=118.469, valence=0.779, year=1928),
#  Row(acousticness=0.994, artists="['Robert Schumann', 'Vladimir Horowitz']", danceability=0.379, duration_ms=282133, energy=0.0135, explicit=0, id='6KuQTIu1KoTTkLXKrwlLPV', instrumentalness=0.901, key=8, liveness=0.0763, loudness=-28.454, mode=1, name='Fantasiestücke, Op. 111: Più tosto lento', popularity=0, release_date='1928', speechiness=0.0462, tempo=83.97200000000002, valence=0.0767, year=1928)]

# %%
#".first(num)" Returns first row as a list.
spotify.first()
# Out:
# Row(acousticness=0.995, artists="['Carl Woitschach']", danceability=0.708, duration_ms=158648, energy=0.195, explicit=0, id='6KbQ3uYMLKb5jDxLF7wYDD', instrumentalness=0.563, key=10, liveness=0.151, loudness=-12.428, mode=1, name='Singende Bataillone 1. Teil', popularity=0, release_date='1928', speechiness=0.0506, tempo=118.469, valence=0.779, year=1928)

# %%
#".tail(num)" Returns last num of rows as a list.
spotify.tail(1)
# Out:
# [Row(acousticness=0.109, artists="['Ingrid Andress']", danceability=0.512, duration_ms=214787, energy=0.428, explicit=0, id='60RFlt48hm0l4Fu0JoccOl', instrumentalness=0.0, key=0, liveness=0.105, loudness=-7.387, mode=1, name='More Hearts Than Mine', popularity=65, release_date='2020-03-27', speechiness=0.0271, tempo=80.58800000000002, valence=0.366, year=2020)]

# %%
#".describe(cols)" doesnt return anything special
spotify.describe()
# Out:
# DataFrame[summary: string, acousticness: string, artists: string, danceability: string, duration_ms: string, energy: string, explicit: string, id: string, instrumentalness: string, key: string, liveness: string, loudness: string, mode: string, name: string, popularity: string, release_date: string, speechiness: string, tempo: string, valence: string, year: string]

# %%
#Playing with Expresions: Transformation on one or more values in a row

#4Ways to transform the columns.

from pyspark.sql.functions import expr
spotify.select(expr('danceability+1')).first()
# Out:
# Row((danceability + 1)=1.708)

# %%
from pyspark.sql.functions import expr
spotify.select(expr('danceability')+1).first()
# Out:
# Row((danceability + 1)=1.708)

# %%
from pyspark.sql.functions import col
spotify.select(col('danceability')+1).first()
# Out:
# Row((danceability + 1)=1.708)

# %%
#Column projection: Project a set of columns

#2Ways of using it.
spotify.select('danceability').show(1)
# Out:
# +------------+
# |danceability|
# +------------+
# |       0.708|
# +------------+
# only showing top 1 row

# %%
spotify.select(col('danceability')).show(1)
# Out:
# +------------+
# |danceability|
# +------------+
# |       0.708|
# +------------+
# only showing top 1 row

# %%
#Displaying the first line for all the columns 
spotify.select(col('*')).show(1)
# Out:
# +------------+-------------------+------------+-----------+------+--------+--------------------+----------------+---+--------+--------+----+--------------------+----------+------------+-----------+-------+-------+----+
# |acousticness|            artists|danceability|duration_ms|energy|explicit|                  id|instrumentalness|key|liveness|loudness|mode|                name|popularity|release_date|speechiness|  tempo|valence|year|
# +------------+-------------------+------------+-----------+------+--------+--------------------+----------------+---+--------+--------+----+--------------------+----------+------------+-----------+-------+-------+----+
# |       0.995|['Carl Woitschach']|       0.708|     158648| 0.195|       0|6KbQ3uYMLKb5jDxLF...|           0.563| 10|   0.151| -12.428|   1|Singende Bataillo...|         0|        1928|     0.0506|118.469|  0.779|1928|
# +------------+-------------------+------------+-----------+------+--------+--------------------+----------------+---+--------+--------+----+--------------------+----------+------------+-----------+-------+-------+----+
# only showing top 1 row

# %%
#"min(), max()" extract min and max values
#".groupBy" columns we want to group by.
#".agg" aggregations to apply to the different groups
from pyspark.sql.functions import min,max,avg


spotify.groupBy('year')\
        .pivot('key')\
        .agg(min('danceability').alias('min_danceability'),\
              max('danceability').alias('max_danceability'),
                avg('danceability').alias('max_danceability'))\
        .toPandas()
# Out:
#     year  0_min_danceability  0_max_danceability  0_max_danceability  \
# 0   1959              0.0764               0.889            0.520399
# 1   1990              0.0618               0.917            0.531802
# 2   1975              0.0641               0.831            0.522083
# 3   1977              0.1640               0.910            0.552396
# 4   1924              0.3460               0.778            0.557786
# ..   ...                 ...                 ...                 ...
# 95  2002              0.1160               0.974            0.542645
# 96  1929              0.1880               0.853            0.647299
# 97  1928              0.1780               0.892            0.546533
# 98  1933              0.0717               0.813            0.591607
# 99  1993              0.1290               0.939            0.560809
#
#     1_min_danceability  1_max_danceability  1_max_danceability  \
# 0                0.116               0.827            0.471822
# 1                0.125               0.895            0.586241
# 2                0.170               0.857            0.523790
# 3                0.000               0.878            0.525596
# 4                0.425               0.753            0.591000
# ..                 ...                 ...                 ...
# 95               0.130               0.932            0.606682
# 96               0.160               0.836            0.670632
# 97               0.196               0.869            0.502676
# 98               0.357               0.845            0.589810
# 99               0.113               0.951            0.609667
#
#     2_min_danceability  2_max_danceability  2_max_danceability  ...  \
# 0               0.0000               0.848            0.452603  ...
# 1               0.0821               0.980            0.505723  ...
# 2               0.0915               0.838            0.514799  ...
# 3               0.0648               0.903            0.520394  ...
# 4               0.3270               0.746            0.523737  ...
# ..                 ...                 ...                 ...  ...
# 95              0.1030               0.964            0.576043  ...
# 96              0.2340               0.872            0.604810  ...
# 97              0.1040               0.868            0.587494  ...
# 98              0.2580               0.813            0.595911  ...
# 99              0.1420               0.933            0.542194  ...
#
#     8_max_danceability  9_min_danceability  9_max_danceability  \
# 0             0.465022              0.1520               0.873
# 1             0.540221              0.1480               0.918
# 2             0.535801              0.2180               0.871
# 3             0.510386              0.1570               0.900
# 4             0.541655              0.3940               0.760
# ..                 ...                 ...                 ...
# 95            0.598924              0.0877               0.985
# 96            0.629750              0.2510               0.838
# 97            0.502619              0.2000               0.876
# 98            0.610814              0.3010               0.809
# 99            0.581505              0.0992               0.945
#
#     9_max_danceability  10_min_danceability  10_max_danceability  \
# 0             0.493903               0.0623                0.865
# 1             0.532600               0.0744                0.936
# 2             0.521813               0.2470                0.870
# 3             0.534520               0.1640                0.912
# 4             0.633267               0.2090                0.813
# ..                 ...                  ...                  ...
# 95            0.585635               0.0747                0.951
# 96            0.677759               0.3550                0.852
# 97            0.570595               0.1620                0.862
# 98            0.594000               0.2490                0.829
# 99            0.555665               0.0866                0.930
#
#     10_max_danceability  11_min_danceability  11_max_danceability  \
# 0              0.492812               0.0814                0.851
# 1              0.585499               0.1610                0.953
# 2              0.559161               0.1890                0.870
# 3              0.567196               0.0823                0.935
# 4              0.533378               0.4710                0.742
# ..                  ...                  ...                  ...
# 95             0.601983               0.1560                0.956
# 96             0.666176               0.2870                0.790
# 97             0.490862               0.1410                0.898
# 98             0.620548               0.2330                0.810
# 99             0.612801               0.0655                0.941
#
#     11_max_danceability
# 0              0.494310
# 1              0.586055
# 2              0.564163
# 3              0.573964
# 4              0.604714
# ..                  ...
# 95             0.613301
# 96             0.671797
# 97             0.499338
# 98             0.566700
# 99             0.622582
#
# [100 rows x 37 columns]

# %%
#".withColumn" adds new column and follows an expresion over this column
### lit() includes the literal, the selected number for the rows on that column

#When we use the action show, we are displaying text (not python object).
from pyspark.sql.functions import lit
spotify.withColumn('favoritos',lit(2)).select(col('favoritos')).show(1)
# Out:
# +---------+
# |favoritos|
# +---------+
# |        2|
# +---------+
# only showing top 1 row

# %%
### upper() capital letters the selected column
from pyspark.sql.functions import upper
spotify.withColumn('favoritos',upper(col('artists'))).select(col('favoritos')).show(1)
# Out:
# +-------------------+
# |          favoritos|
# +-------------------+
# |['CARL WOITSCHACH']|
# +-------------------+
# only showing top 1 row

# %%
#".drop" returns a new dataframe that drops the column specified.
spotify.drop('danceability').toPandas()
# Out:
#         acousticness                                   artists  duration_ms  \
# 0             0.9950                       ['Carl Woitschach']       158648
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']       282133
# 2             0.6040                   ['Seweryn Goszczyński']       104300
# 3             0.9950                      ['Francisco Canaro']       180760
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']       687733
# ...              ...                                       ...          ...
# 169904        0.1730                    ['DripReport', 'Tyga']       163800
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']       167468
# 169906        0.5380                     ['Kygo', 'Oh Wonder']       180700
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']       167308
# 169908        0.1090                        ['Ingrid Andress']       214787
#
#         energy  explicit                      id  instrumentalness  key  \
# 0       0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD          0.563000   10
# 1       0.0135         0  6KuQTIu1KoTTkLXKrwlLPV          0.901000    8
# 2       0.2200         0  6L63VW0PibdM1HDSBoqnoM          0.000000    5
# 3       0.1300         0  6M94FkXd15sOAOQYRnWPN8          0.887000    1
# 4       0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd          0.908000   11
# ...        ...       ...                     ...               ...  ...
# 169904  0.4430         1  4KppkflX7I3vJQk7urOJaS          0.000032    1
# 169905  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ          0.031300    8
# 169906  0.5390         0  52eycxprLhK3lPcRLbQiVk          0.002330    7
# 169907  0.7610         0  3wYOGJYD31sLRmBgCvWxa4          0.000000    1
# 169908  0.4280         0  60RFlt48hm0l4Fu0JoccOl          0.000000    0
#
#         liveness  loudness  mode  \
# 0         0.1510   -12.428     1
# 1         0.0763   -28.454     1
# 2         0.1190   -19.924     0
# 3         0.1110   -14.734     0
# 4         0.0980   -16.829     1
# ...          ...       ...   ...
# 169904    0.0891    -7.461     1
# 169905    0.1110   -10.907     1
# 169906    0.1080    -9.332     1
# 169907    0.2220    -2.557     1
# 169908    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year
# 0              1928       0.0506  118.469   0.7790  1928
# 1              1928       0.0462   83.972   0.0767  1928
# 2              1928       0.9290  107.177   0.8800  1928
# 3        1928-09-25       0.0926  108.003   0.7200  1928
# 4              1928       0.0424   62.149   0.0693  1928
# ...             ...          ...      ...      ...   ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020
# 169905   2020-06-08       0.0403  128.000   0.2700  2020
# 169906   2020-05-29       0.1050  123.700   0.1530  2020
# 169907   2020-02-28       0.0385  129.916   0.4720  2020
# 169908   2020-03-27       0.0271   80.588   0.3660  2020
#
# [169909 rows x 18 columns]

# %%
#RENAMING COLUMNS (2ways)
##'.withColumnRenamed' returns a new Dataframe by renaming an existing column
spotify.withColumnRenamed('name','song').printSchema()
# Out:
# root
#  |-- acousticness: double (nullable = true)
#  |-- artists: string (nullable = true)
#  |-- danceability: double (nullable = true)
#  |-- duration_ms: integer (nullable = true)
#  |-- energy: double (nullable = true)
#  |-- explicit: integer (nullable = true)
#  |-- id: string (nullable = true)
#  |-- instrumentalness: double (nullable = true)
#  |-- key: integer (nullable = true)
#  |-- liveness: double (nullable = true)
#  |-- loudness: double (nullable = true)
#  |-- mode: integer (nullable = true)
#  |-- song: string (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- speechiness: double (nullable = true)
#  |-- tempo: double (nullable = true)
#  |-- valence: double (nullable = true)
#  |-- year: integer (nullable = true)

# %%
#'.select(...,col(colName).alias(newName))'
spotify.select(col('name').alias('song')).show(1)
# Out:
# +--------------------+
# |                song|
# +--------------------+
# |Singende Bataillo...|
# +--------------------+
# only showing top 1 row

# %%
spotify.toPandas()
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# 0            158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1            282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2            104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3            180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4            687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
# ...             ...     ...       ...                     ...
# 169904       163800  0.4430         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700  0.5390         0  52eycxprLhK3lPcRLbQiVk
# 169907       167308  0.7610         0  3wYOGJYD31sLRmBgCvWxa4
# 169908       214787  0.4280         0  60RFlt48hm0l4Fu0JoccOl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.563000   10    0.1510   -12.428     1
# 1               0.901000    8    0.0763   -28.454     1
# 2               0.000000    5    0.1190   -19.924     0
# 3               0.887000    1    0.1110   -14.734     0
# 4               0.908000   11    0.0980   -16.829     1
# ...                  ...  ...       ...       ...   ...
# 169904          0.000032    1    0.0891    -7.461     1
# 169905          0.031300    8    0.1110   -10.907     1
# 169906          0.002330    7    0.1080    -9.332     1
# 169907          0.000000    1    0.2220    -2.557     1
# 169908          0.000000    0    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year
# 0              1928       0.0506  118.469   0.7790  1928
# 1              1928       0.0462   83.972   0.0767  1928
# 2              1928       0.9290  107.177   0.8800  1928
# 3        1928-09-25       0.0926  108.003   0.7200  1928
# 4              1928       0.0424   62.149   0.0693  1928
# ...             ...          ...      ...      ...   ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020
# 169905   2020-06-08       0.0403  128.000   0.2700  2020
# 169906   2020-05-29       0.1050  123.700   0.1530  2020
# 169907   2020-02-28       0.0385  129.916   0.4720  2020
# 169908   2020-03-27       0.0271   80.588   0.3660  2020
#
# [169909 rows x 19 columns]

# %%
#".filter" returns the condition as expressions. Rows not satisfying the expressions are removed.
spotify.filter((col('year')>1950)&(col("key")==8)).toPandas()
# Out:
#       acousticness                                            artists  \
# 0           0.9930         ['Modest Mussorgsky', 'Vladimir Horowitz']
# 1           0.9930                                        ['Suraiya']
# 2           0.9720  ['Wolfgang Amadeus Mozart', 'János Starker', '...
# 3           0.8370                 ['Jean Cocteau', 'André Parinaud']
# 4           0.9270  ['Giuseppe Verdi', 'Mario Rossi', 'Orchestra S...
# ...            ...                                                ...
# 8543        0.4100  ['Rauw Alejandro', 'Myke Towers', 'Sky Rompien...
# 8544        0.0274           ['Lil Tjay', 'Sheff G', 'Sleepy Hallow']
# 8545        0.2540                     ['YoungBoy Never Broke Again']
# 8546        0.2100                           ['LEGADO 7', 'Junior H']
# 8547        0.0167                 ['Leon Bridges', 'Terrace Martin']
#
#       danceability  duration_ms   energy  explicit                      id  \
# 0            0.343        48893  0.00569         0  1DYFmyH2msGdqbjXN3PQLw
# 1            0.711       175893  0.19400         0  1FEMTgmhb085sNTS9ULaLR
# 2            0.226       295240  0.10100         0  1GB2OfagSmTEDh1SfkoRkv
# 3            0.644       278773  0.16100         0  1IYRWBduCAc8zZxpC9JFnz
# 4            0.361        60133  0.17600         0  1McAIVgWsaqFte8P2VRjsL
# ...            ...          ...      ...       ...                     ...
# 8543         0.809       184817  0.62400         1  10u2iOS0r6plfb9GknD7g4
# 8544         0.701       191904  0.64500         1  0w1x05XBSRIuVmKd3D0IPd
# 8545         0.506       175339  0.78700         1  0KVEBQA98JvkmB5ZydQ13k
# 8546         0.795       218501  0.58500         0  52Cpyvd2dKb6XRn313nH87
# 8547         0.719       167468  0.38500         0  1ehhGlTvjtHo2e4xJFB0SZ
#
#       instrumentalness  key  liveness  loudness  mode  \
# 0             0.797000    8    0.1320   -36.382     1
# 1             0.353000    8    0.0511   -10.538     1
# 2             0.889000    8    0.2190   -20.036     1
# 3             0.000000    8    0.1310   -20.258     0
# 4             0.000064    8    0.1590   -20.104     1
# ...                ...  ...       ...       ...   ...
# 8543          0.000000    8    0.1080    -4.963     0
# 8544          0.000174    8    0.3270    -3.084     0
# 8545          0.000000    8    0.1120    -6.634     1
# 8546          0.000001    8    0.1120    -4.451     1
# 8547          0.031300    8    0.1110   -10.907     1
#
#                                                    name  popularity  \
# 0     Pictures at an Exhibition: Promenade. Moderato...           0
# 1                              Raaste Pe Ham Khade Hain           0
# 2     Cello Concerto in E-Flat Major, K. 285: II. Ro...           0
# 3                            Le surréalisme / La poésie           0
# 4     Verdi : Luisa Miller : Act 1 "Costarti, o vecc...           0
# ...                                                 ...         ...
# 8543                                       Ponte Pa' Mi          79
# 8544                                    Wet Em Up Pt. 2          67
# 8545                                       Fine By Time          64
# 8546                                    Ojos De Maniaco          68
# 8547                     Sweeter (feat. Terrace Martin)          64
#
#      release_date  speechiness    tempo  valence  year
# 0            1951       0.0419   96.856    0.466  1951
# 1      1951-01-01       0.0959  125.975    0.811  1951
# 2      1951-10-11       0.0440   75.230    0.156  1951
# 3            1951       0.5880   99.224    0.428  1951
# 4            1951       0.2950  160.588    0.155  1951
# ...           ...          ...      ...      ...   ...
# 8543   2020-04-16       0.1550   85.011    0.629  2020
# 8544   2020-05-08       0.1640  107.955    0.576  2020
# 8545   2020-02-21       0.1610   99.956    0.333  2020
# 8546   2020-02-28       0.0374   97.479    0.934  2020
# 8547   2020-06-08       0.0403  128.000    0.270  2020
#
# [8548 rows x 19 columns]

# %%
#".where" works in the same way as filter
#".limit" limit the results to the specified number.
spotify.where((col('year')>1950)&(col("key")==8)).limit(5).toPandas()
# Out:
#    acousticness                                            artists  \
# 0         0.993         ['Modest Mussorgsky', 'Vladimir Horowitz']
# 1         0.993                                        ['Suraiya']
# 2         0.972  ['Wolfgang Amadeus Mozart', 'János Starker', '...
# 3         0.837                 ['Jean Cocteau', 'André Parinaud']
# 4         0.927  ['Giuseppe Verdi', 'Mario Rossi', 'Orchestra S...
#
#    danceability  duration_ms   energy  explicit                      id  \
# 0         0.343        48893  0.00569         0  1DYFmyH2msGdqbjXN3PQLw
# 1         0.711       175893  0.19400         0  1FEMTgmhb085sNTS9ULaLR
# 2         0.226       295240  0.10100         0  1GB2OfagSmTEDh1SfkoRkv
# 3         0.644       278773  0.16100         0  1IYRWBduCAc8zZxpC9JFnz
# 4         0.361        60133  0.17600         0  1McAIVgWsaqFte8P2VRjsL
#
#    instrumentalness  key  liveness  loudness  mode  \
# 0          0.797000    8    0.1320   -36.382     1
# 1          0.353000    8    0.0511   -10.538     1
# 2          0.889000    8    0.2190   -20.036     1
# 3          0.000000    8    0.1310   -20.258     0
# 4          0.000064    8    0.1590   -20.104     1
#
#                                                 name  popularity release_date  \
# 0  Pictures at an Exhibition: Promenade. Moderato...           0         1951
# 1                           Raaste Pe Ham Khade Hain           0   1951-01-01
# 2  Cello Concerto in E-Flat Major, K. 285: II. Ro...           0   1951-10-11
# 3                         Le surréalisme / La poésie           0         1951
# 4  Verdi : Luisa Miller : Act 1 "Costarti, o vecc...           0         1951
#
#    speechiness    tempo  valence  year
# 0       0.0419   96.856    0.466  1951
# 1       0.0959  125.975    0.811  1951
# 2       0.0440   75.230    0.156  1951
# 3       0.5880   99.224    0.428  1951
# 4       0.2950  160.588    0.155  1951

# %%
spotify.select(col('year')).distinct().show()
# Out:
# +----+
# |year|
# +----+
# |1959|
# |1990|
# |1975|
# |1977|
# |1924|
# |2003|
# |2007|
# |2018|
# |1974|
# |2015|
# |1927|
# |1955|
# |2006|
# |1978|
# |1925|
# |1961|
# |2013|
# |1942|
# |1939|
# |1944|
# +----+
# only showing top 20 rows

# %%
#".distinct" dataframe containing the distinct rows
spotify.select(col('artists')).distinct().show()
# Out:
# +--------------------+
# |             artists|
# +--------------------+
# |    ['The Drifters']|
# |   ['Wanda Jackson']|
# |['Elvis Presley',...|
# |['Martha Reeves &...|
# |['Blue Öyster Cult']|
# |['Earth, Wind & F...|
# |     ['Joe Jackson']|
# |  ['Alain Barrière']|
# |        ['Headpins']|
# |['Rickie Lee Jones']|
# |['Archie Shepp', ...|
# |     ['Miguel Bosé']|
# |['The Flaming Lips']|
# |    ['Stiff Dylans']|
# |['Maurice Ravel',...|
# |    ['Cody Johnson']|
# |          ['VÉRITÉ']|
# |['Los Cadetes De ...|
# |         ['Agust D']|
# |    ['Hameeda Bano']|
# +--------------------+
# only showing top 20 rows

# %%
#".dropDuplicates" returns the dataframe w/o duplicates.
display(Markdown("This DataFrame has **%d rows**." % spotify.dropDuplicates().count()))
# Out:
# This DataFrame has **169909 rows**.

# %%
#".orderBy" or ".sort" returns a dataframe sorted
#sort direction can be: asc, desc, asc_nulls_first,desc_nulls_first, asc_nulls_last and desc_nulls_last
spotify.sort(col('year')).limit(5).toPandas()
# Out:
#    acousticness                                            artists  \
# 0         0.941                                     ['Dennis Day']
# 1         0.996                                 ['John McCormack']
# 2         0.982  ['Sergei Rachmaninoff', 'James Levine', 'Berli...
# 3         0.732                                     ['Dennis Day']
# 4         0.957                                     ['Phil Regan']
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.241       196307   0.274         0  4aVy85Y2sxMwIKmAcimHp0
# 1         0.518       159507   0.203         0  5uNZnElqOS3W4fRmRYPk4T
# 2         0.279       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz
# 3         0.819       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8
# 4         0.418       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6
#
#    instrumentalness  key  liveness  loudness  mode  \
# 0          0.000008    0    0.0984    -9.750     0
# 1          0.000000    0    0.1150   -10.589     1
# 2          0.878000   10    0.6650   -20.096     1
# 3          0.000000    7    0.1600   -12.441     1
# 4          0.000002    3    0.2290   -10.096     1
#
#                                                 name  popularity release_date  \
# 0                           How Can You Buy Killarny           2         1921
# 1                           The Wearing of the Green           5         1921
# 2  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           5         1921
# 3                            Clancy Lowered the Boom           7         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo  valence  year
# 0       0.0297   90.773   0.2120  1921
# 1       0.0615   66.221   0.4060  1921
# 2       0.0366   80.954   0.0594  1921
# 3       0.4150   60.936   0.9630  1921
# 4       0.0380  101.665   0.2530  1921

# %%
from pyspark.sql.functions import countDistinct
print("Checking amount of distinct values in some columns")
spotify.select([countDistinct(c).alias(c) for c in ['year','explicit','name']]).show()
# Out:
# Checking amount of distinct values in some columns
# [Stage 142:==============================================>      (174 + 2) / 200]
# +----+--------+------+
# |year|explicit|  name|
# +----+--------+------+
# | 100|       2|132940|
# +----+--------+------+

# %%
spotify_years = spotify.withColumn('year', substring('year',1,4)).select('year').distinct().show()
# Out:
# +----+
# |year|
# +----+
# |1953|
# |1957|
# |1987|
# |1956|
# |1936|
# |2016|
# |2012|
# |2020|
# |1958|
# |1943|
# |1972|
# |1931|
# |1988|
# |1926|
# |1938|
# |2019|
# |2017|
# |1932|
# |1977|
# |1971|
# +----+
# only showing top 20 rows

# %%
from pyspark.sql.functions import length
#"length()" get the lenght of the values for a column
spotify.withColumn('year_lenght',length('year')).select('year_lenght').distinct().show()
# Out:
# +-----------+
# |year_lenght|
# +-----------+
# |          4|
# +-----------+

# %%
#"round()" Round up the given value
from pyspark.sql.functions import round
spotify.select(round('loudness').alias('round')).limit(5).show()
# Out:
# +-----+
# |round|
# +-----+
# |-12.0|
# |-28.0|
# |-20.0|
# |-15.0|
# |-17.0|
# +-----+

# %%
#"bround()" Round down the given value
from pyspark.sql.functions import bround
spotify.select(bround('loudness').alias('bround')).limit(5).show()
# Out:
# +------+
# |bround|
# +------+
# | -12.0|
# | -28.0|
# | -20.0|
# | -15.0|
# | -17.0|
# +------+

# %%
#"corr(col1,col2)" returns a new column for the Pearson Correlation Coefficient
from pyspark.sql.functions import col, corr
spotify.select(corr(col('acousticness'),col('danceability'))).show()
# Out:
# +--------------------------------+
# |corr(acousticness, danceability)|
# +--------------------------------+
# |             -0.2659502509484105|
# +--------------------------------+

# %%
#"column.getItem(position)" gets an item at position ordinal out of the array
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import split,col
from pyspark.sql import Row

spotify.withColumn("split_date",split("release_date","-"or"/") )\
        .withColumn('year',col("split_date").getItem(0))\
        .withColumn('month',col("split_date").getItem(1))\
        .withColumn('day',col("split_date").getItem(2))\
        .select("release_date","day","month","year")\
        .show()
# Out:
# +------------+----+-----+----+
# |release_date| day|month|year|
# +------------+----+-----+----+
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-09-25|  25|   09|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-10-03|  03|   10|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-01-01|  01|   01|1928|
# |        1928|null| null|1928|
# |        1928|null| null|1928|
# |  1928-09-16|  16|   09|1928|
# |        1928|null| null|1928|
# |  1928-09-17|  17|   09|1928|
# +------------+----+-----+----+
# only showing top 20 rows

# %% [markdown]
# Introduce a rating

# %%
spotify\
    .withColumn('CenturyQuarters', when(col('year')<=1946,"1921-1946") \
                               .when(col('year')<=1971,"1946-1971")\
                               .when(col('year')<=1996,"1971-1996")\
                               .when(col('year')<=2021,"1996-1921")\
                               .otherwise("unacceptable"))\
    .select(col('CenturyQuarters')).distinct()\
    .show()
# Out:
# +---------------+
# |CenturyQuarters|
# +---------------+
# |      1921-1946|
# |      1946-1971|
# |      1996-1921|
# |      1971-1996|
# +---------------+

# %% [markdown]
# How do we call a column? Well.. there are 4 different ways:

# %%
spotify['year']
# Out:
# Column<b'year'>

# %%
spotify.year
# Out:
# Column<b'year'>

# %%
from pyspark.sql.functions import col
col('year')
# Out:
# Column<b'year'>

# %%
from pyspark.sql.functions import column
column('year')
# Out:
# Column<b'year'>
